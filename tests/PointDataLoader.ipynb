# %%
import sys 
sys.path.append(rf"/nfs/home/genovese/thesis-wildfire-genovese/src")
from importlib import reload
import utils
reload(utils)
from utils import *

sys.path.append(rf"/nfs/home/genovese/thesis-wildfire-genovese/src/OnFireForest")
import PointDataLoader
reload(PointDataLoader)
from PointDataLoader import PointDataLoader

# %%
ignitions = gpd.read_file('/nfs/home/genovese/thesis-wildfire-genovese/data/nicola/piedmont_2012_2024_fa.geojson').to_crs(epsg=3857)
gdf = separate_date(ignitions, 'initialdate')
row = gdf.iloc[[1206], :]

# %%
test = PointDataLoader()
test.set_coordinates(anno = row.YYYY.iloc[0], mese=row.MM.iloc[0], giorno=row.DD.iloc[0], x=row.point_x.iloc[0], y=row.point_y.iloc[0], crs=row.crs)
test.get_coordinates()
# Out:
# {'anno': 2023,
#  'mese': 4,
#  'giorno': 4,
#  'coordinate': <POINT (856763.136 5686588.315)>}

# %%
test.load()
table = test.get_table()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2129040/245485090.py in ?()
# ----> 1 test.load()
#       2 table = test.get_table()
#
# ~/thesis-wildfire-genovese/src/OnFireForest/PointDataLoader.py in ?(self, db_path)
#      76         vegetazione_path = os.path.join(db_path, f'vegetazione.geojson')
#      77         strade_path = os.path.join(db_path, f'strade.geojson')
#      78         meteo_path = os.path.join(db_path, f'meteo_{self.__anno}.geojson')
#      79
# ---> 80         point_data.gather_point_data(gpd.read_file(per_comune_path).to_crs(epsg=3857),
#      81                                      gpd.read_file(altimetria_path).to_crs(epsg=3857),
#      82                                      gpd.read_file(vegetazione_path).to_crs(epsg=3857),
#      83                                      gpd.read_file(strade_path).to_crs(epsg=3857),
#
# ...

# %%
table.describe()
# Out:
#        analfabeti  alfabeti privi di titolo di studio  \
# count         0.0                                 0.0
# mean          NaN                                 NaN
# std           NaN                                 NaN
# min           NaN                                 NaN
# 25%           NaN                                 NaN
# 50%           NaN                                 NaN
# 75%           NaN                                 NaN
# max           NaN                                 NaN
#
#        licenza di scuola elementare  \
# count                           0.0
# mean                            NaN
# std                             NaN
# min                             NaN
# 25%                             NaN
# 50%                             NaN
# 75%                             NaN
# max                             NaN
#
#        licenza di scuola media inferiore o di avviamento professionale  \
# count                                                0.0
# ...
