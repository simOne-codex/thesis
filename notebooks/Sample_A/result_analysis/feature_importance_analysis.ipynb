# %%
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
with open('/nfs/home/genovese/thesis-wildfire-genovese/src/trained_models/final_model.pkl', 'rb') as f:
    r_model = pickle.load(f)

with open('/nfs/home/genovese/thesis-wildfire-genovese/src/trained_models/final_classification_model.pkl', 'rb') as f:
    c_model = pickle.load(f)

with open ('/nfs/home/genovese/thesis-wildfire-genovese/src/trained_models/pca.pkl', 'rb') as f:
    pca = pickle.load(f)
    
X_train = pd.read_csv('/nfs/home/genovese/thesis-wildfire-genovese/database/model_input/X_train_val_rekriged.csv').set_index('fire_id', drop=True).drop(columns='Unnamed: 0')
old_features = pd.read_csv('/nfs/home/genovese/thesis-wildfire-genovese/database/model_input/not_imputed_dataset_rekriged.csv', index_col=0).drop(columns=['fire_id', 'target', 'label']).columns

# %%
rf = pd.Series(r_model.feature_importances_, index=X_train.columns).sort_values(ascending=False)
cf = pd.Series(c_model.feature_importances_, index=X_train.columns).sort_values(ascending=False)

# %%
print(rf, '\n \n')
print(cf)
# Out:
# PC4            0.254538
# PC2            0.160914
# PC12           0.083798
# PC10           0.043424
# PC5            0.039752
# PC3            0.038492
# PC15           0.035929
# sentinel_34    0.029653
# PC6            0.029230
# sentinel_4     0.021962
# sentinel_13    0.021394
# sentinel_12    0.020685
# sentinel_28    0.020335
# sentinel_18    0.018990
# sentinel_10    0.018135
# sentinel_25    0.017906
# sentinel_22    0.017648
# sentinel_3     0.017354
# sentinel_23    0.017221
# sentinel_32    0.017073
# sentinel_21    0.016868
# sentinel_35    0.015452
# sentinel_8     0.015180
# sentinel_36    0.014123
# sentinel_30    0.013945
# dtype: float64
#
#
# PC4            0.119539
# PC2            0.116083
# PC3            0.074472
# PC12           0.072076
# PC5            0.056697
# sentinel_34    0.043387
# PC10           0.040965
# PC15           0.039894
# PC6            0.039541
# sentinel_18    0.032697
# sentinel_13    0.032142
# sentinel_22    0.030056
# sentinel_12    0.029124
# sentinel_3     0.025122
# sentinel_10    0.025058
# sentinel_4     0.024990
# sentinel_25    0.024244
# sentinel_28    0.023945
# sentinel_32    0.023713
# sentinel_23    0.022996
# sentinel_35    0.022937
# sentinel_36    0.021054
# sentinel_21    0.020248
# sentinel_30    0.019526
# sentinel_8     0.019491
# dtype: float64

# %%
pca_transform = pd.DataFrame(pca.components_, columns = [f'PC{n}' for n in range(1, 379)], index=old_features)
r_loadings = pca_transform.loc[:, [pc for pc in rf.index if 'PC' in pc]]
c_loadings = pca_transform.loc[:, [pc for pc in cf.index if 'PC' in pc]]

# %%
for col in pd.Series(list(r_loadings.columns)+list(c_loadings.columns)).unique():
    print(f"\nTop features for {col}:")
    top_features = r_loadings.loc[:, col].abs().sort_values(ascending=False).head(30)
    print(top_features)

for col in r_loadings.columns:
    print(f"\nTop features for {col}:")
    top_features = r_loadings.loc[:, col].abs().sort_values(ascending=False).head(30)
    print(top_features)
# Out:
# Top features for PC4:
# VEGETAZIONE_TIPO_Pineta di pino uncinato eretto                                  0.421700
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris    0.287288
# VEGETAZIONE_TIPO_Querceto di rovere a Potentilla alba                            0.276146
# VEGETAZIONE_TIPO_?                                                               0.242826
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                                   0.209846
# VEGETAZIONE_TIPO_Pineta mesalpica acidofila di pino silvestre                    0.187604
# VEGETAZIONE_TIPO_Pineta mesalpica basifila di pino silvestre                     0.172167
# VEGETAZIONE_INTERVENTO_Diradamento e conversione                                 0.169770
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale                                 0.158889
# VEGETAZIONE_INTERVENTO_Formazione lineare                                        0.149991
# VEGETAZIONE_TIPO_Pecceta montana mesalpica                                       0.148084
# VEGETAZIONE_INTERVENTO_Ceduazione                                                0.146454
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                 0.141671
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale per collettivi                  0.141411
# VEGETAZIONE_INTERVENTO_Aree per cui non si prevede intervento                    0.139687
# VEGETAZIONE_TIPO_Cerreta mesofila                                                0.136565
# VEGETAZIONE_TIPO_Specie esotiche o naturalizzate                                 0.131005
# VEGETAZIONE_TIPO_Faggeta basifila pioniera                                       0.128110
# VEGETAZIONE_TIPO_Pecceta montana endalpica                                       0.121473
# VEGETAZIONE_TIPO_Abetina altimontana a megaforbie                                0.120966
# VEGETAZIONE_TIPO_Abetina eutrofica                                               0.119384
# VEGETAZIONE_TIPO_Lariceto a megaforbie                                           0.115513
# VEGETAZIONE_TIPO_Pineta endalpica mesoxerofila di pino silvestre                 0.113548
# VEGETAZIONE_TIPO_Faggeta mesoxerofila                                            0.109753
# VEGETAZIONE_TIPO_Pineta endalpica acidofila di pino silvestre                    0.109244
# VEGETAZIONE_TIPO_Betuleto montano                                                0.104924
# VEGETAZIONE_TIPO_Pineta endalpica basifila di pino silvestre                     0.100173
# VEGETAZIONE_TIPO_Lariceto montano                                                0.098562
# VEGETAZIONE_TIPO_Specie spontanee                                                0.091584
# analfabeti                                                                       0.087734
# Name: PC4, dtype: float64
#
# Top features for PC2:
# VEGETAZIONE_TIPO_Querceto di rovere/roverella con orniello ed Erica cinerea                0.485089
# VEGETAZIONE_TIPO_Faggeta eutrofica delle Alpi                                              0.279103
# VEGETAZIONE_TIPO_Lariceto pascolivo                                                        0.260871
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris              0.235312
# VEGETAZIONE_TIPO_Acero-tiglio-frassineto di forra                                          0.212371
# VEGETAZIONE_TIPO_Querco-tiglieto                                                           0.202583
# VEGETAZIONE_TIPO_Abetina oligotrofica mesalpica                                            0.174289
# VEGETAZIONE_TIPO_Querco-carpineto mesoxerofilo del Monferrato e/o Colline del Po           0.170046
# VEGETAZIONE_TIPO_Cerreta mesofila                                                          0.168613
# VEGETAZIONE_TIPO_Querceto di rovere a Teucrium scorodonia                                  0.160752
# VEGETAZIONE_TIPO_Castagneto da frutto                                                      0.158994
# VEGETAZIONE_TIPO_Faggeta basifila pioniera                                                 0.155563
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                           0.138327
# VEGETAZIONE_TIPO_Pineta mesalpica acidofila di pino silvestre                              0.136883
# VEGETAZIONE_TIPO_Pineta di pino montano prostrato                                          0.133785
# VEGETAZIONE_TIPO_Alneto di ontano bianco                                                   0.131314
# VEGETAZIONE_TIPO_Pineta endalpica basifila di pino silvestre                               0.128794
# VEGETAZIONE_TIPO_Betuleto montano                                                          0.119013
# VEGETAZIONE_TIPO_Pecceta subalpina                                                         0.116707
# VEGETAZIONE_TIPO_Pecceta montana mesalpica                                                 0.116582
# VEGETAZIONE_TIPO_Specie spontanee                                                          0.113543
# VEGETAZIONE_TIPO_Pineta di brughiera su morene e terrazzi fluvio-glaciali                  0.109054
# VEGETAZIONE_TIPO_Orno-ostrieto delle Alpi Liguri e Marittime                               0.099711
# VEGETAZIONE_TIPO_Pecceta montana endalpica                                                 0.095383
# VEGETAZIONE_TIPO_Castagneto neutrofilo dell'Appennino e dei rilievi collinari interni\n    0.088922
# analfabeti                                                                                 0.087459
# VEGETAZIONE_TIPO_Lariceto mesoxerofilo subalpino                                           0.085446
# VEGETAZIONE_TIPO_Querceto mesoxerofilo di roverella delle Alpi                             0.082492
# VEGETAZIONE_TIPO_Arbusteto appenninico ad Erica arborea\n                                  0.079473
# VEGETAZIONE_TIPO_Faggeta mesoxerofila                                                      0.072199
# Name: PC2, dtype: float64
#
# Top features for PC12:
# VEGETAZIONE_TIPO_Querceto di rovere a Potentilla alba                            0.356873
# VEGETAZIONE_TIPO_Specie esotiche o naturalizzate                                 0.322010
# VEGETAZIONE_INTERVENTO_Conversione attiva                                        0.291351
# VEGETAZIONE_TIPO_?                                                               0.261016
# VEGETAZIONE_TIPO_Lariceto a megaforbie                                           0.191710
# VEGETAZIONE_TIPO_Pecceta montana endalpica                                       0.189567
# VEGETAZIONE_TIPO_Pineta endalpica di greto di pino silvestre                     0.185815
# VEGETAZIONE_TIPO_Lariceto di greto                                               0.181321
# VEGETAZIONE_TIPO_Specie spontanee                                                0.164829
# VEGETAZIONE_TIPO_Pineta endalpica mesoxerofila di pino silvestre                 0.157212
# VEGETAZIONE_TIPO_Pineta di pino uncinato eretto                                  0.148936
# VEGETAZIONE_INTERVENTO_Tagli successivi adattati                                 0.136668
# VEGETAZIONE_INTERVENTO_Evoluzione controllata (senza gestione attiva)            0.135995
# VEGETAZIONE_TIPO_Faggeta mesoxerofila                                            0.133383
# VEGETAZIONE_INTERVENTO_Taglio a buche, a strisce, a fessura                      0.130737
# VEGETAZIONE_INTERVENTO_Gestione a ceduo composto                                 0.126267
# VEGETAZIONE_TIPO_Pecceta subalpina                                               0.125958
# VEGETAZIONE_INTERVENTO_Evoluzione naturale                                       0.118591
# VEGETAZIONE_TIPO_Faggeta altimontana a megaforbie                                0.118185
# VEGETAZIONE_TIPO_Cembreta xero-acidofila                                         0.117276
# VEGETAZIONE_INTERVENTO_Diradamento e conversione                                 0.116897
# VEGETAZIONE_TIPO_Faggeta basifila pioniera                                       0.113922
# VEGETAZIONE_TIPO_Rimboschimento del piano subalpino                              0.113578
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris    0.110037
# VEGETAZIONE_INTERVENTO_Ceduazione                                                0.103912
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                                   0.103377
# VEGETAZIONE_TIPO_Pineta endalpica acidofila di pino silvestre                    0.102848
# VEGETAZIONE_TIPO_Castagneto da frutto                                            0.102257
# analfabeti                                                                       0.087643
# VEGETAZIONE_TIPO_Querceto di rovere/roverella con orniello ed Erica cinerea      0.086537
# Name: PC12, dtype: float64
#
# Top features for PC10:
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale per collettivi                             0.504016
# VEGETAZIONE_INTERVENTO_Formazione lineare                                                   0.426128
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale                                            0.344764
# VEGETAZIONE_PRIORITA_Differibile - tra 11 e 15 anni                                         0.206074
# VEGETAZIONE_PRIORITA_Aree per cui non si prevede priorita' d'intervento                     0.165652
# VEGETAZIONE_TIPO_Pineta di pino uncinato eretto                                             0.146927
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris               0.143423
# VEGETAZIONE_INTERVENTO_Trasformazione                                                       0.140371
# VEGETAZIONE_PRIORITA_Nessuna                                                                0.137397
# VEGETAZIONE_TIPO_Faggeta mesotrofica                                                        0.133122
# VEGETAZIONE_INTERVENTO_Tagli successivi adattati                                            0.117520
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                            0.110941
# VEGETAZIONE_DESTINAZ_Categorie di uso del suolo per cui non e' prevista una destinazione    0.109012
# VEGETAZIONE_TIPO_Pineta di pino montano prostrato                                           0.106860
# VEGETAZIONE_DESTINAZ_Protettiva                                                             0.103586
# VEGETAZIONE_TIPO_Pecceta montana mesalpica                                                  0.091817
# VEGETAZIONE_INTERVENTO_Ceduazione                                                           0.090959
# VEGETAZIONE_ASSETTO_Ceduo a sterzo (ceduo disetaneo)                                        0.089631
# analfabeti                                                                                  0.087621
# VEGETAZIONE_PRIORITA_Nessun intervento                                                      0.086474
# VEGETAZIONE_PRIORITA_Breve termine - entro 5 anni                                           0.083957
# VEGETAZIONE_TIPO_Lariceto a megaforbie                                                      0.083738
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                                              0.083060
# VEGETAZIONE_TIPO_Acero-tiglio-frassineto di forra                                           0.082529
# VEGETAZIONE_PRIORITA_Medio termine - tra 6 e 10 anni                                        0.082056
# VEGETAZIONE_INTERVENTO_Evoluzione controllata                                               0.081908
# VEGETAZIONE_DESTINAZ_Mantenimento delle praterie di altitudine                              0.081128
# VEGETAZIONE_TIPO_Lariceto montano                                                           0.077044
# VEGETAZIONE_ASSETTO_Bosco di neoformazione (invasione)                                      0.076061
# VEGETAZIONE_TIPO_Pecceta montana endalpica                                                  0.075841
# Name: PC10, dtype: float64
#
# Top features for PC5:
# VEGETAZIONE_TIPO_Pineta di pino montano prostrato                                       0.390936
# VEGETAZIONE_INTERVENTO_Ricostituzione boschiva, taglio fitosanitario o rinfoltimento    0.345285
# VEGETAZIONE_TIPO_Pineta endalpica basifila di pino silvestre                            0.199455
# VEGETAZIONE_TIPO_Querceto mesoxerofilo di roverella delle Alpi                          0.199445
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                        0.198252
# VEGETAZIONE_TIPO_Abetina oligotrofica mesalpica                                         0.186243
# VEGETAZIONE_INTERVENTO_Taglio a buche, a strisce, a fessura                             0.173255
# VEGETAZIONE_TIPO_Cembreta xero-acidofila                                                0.170711
# VEGETAZIONE_TIPO_Alneto di ontano verde                                                 0.160328
# VEGETAZIONE_TIPO_Abetina altimontana a megaforbie                                       0.159724
# VEGETAZIONE_INTERVENTO_Evoluzione libera                                                0.158406
# VEGETAZIONE_TIPO_Rimboschimento del piano subalpino                                     0.154170
# VEGETAZIONE_INTERVENTO_Ceduazione                                                       0.143081
# VEGETAZIONE_TIPO_Pineta mesalpica basifila di pino silvestre                            0.136434
# VEGETAZIONE_TIPO_Specie esotiche o naturalizzate                                        0.133700
# VEGETAZIONE_TIPO_?                                                                      0.129834
# VEGETAZIONE_INTERVENTO_Gestione a ceduo composto                                        0.127236
# VEGETAZIONE_INTERVENTO_Diradamento e conversione                                        0.122380
# VEGETAZIONE_PRIORITA_Nessuna                                                            0.122322
# VEGETAZIONE_TIPO_Lariceto mesoxerofilo subalpino                                        0.118991
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale per collettivi                         0.117083
# VEGETAZIONE_TIPO_Alneto di ontano bianco                                                0.116771
# VEGETAZIONE_TIPO_Faggeta eutrofica delle Alpi                                           0.115916
# VEGETAZIONE_TIPO_Lariceto dei campi di massi                                            0.112283
# VEGETAZIONE_INTERVENTO_Evoluzione controllata (senza gestione attiva)                   0.108010
# VEGETAZIONE_INTERVENTO_Aree per cui non si prevede intervento                           0.107014
# VEGETAZIONE_TIPO_Pineta di brughiera su morene e terrazzi fluvio-glaciali               0.105899
# VEGETAZIONE_INTERVENTO_Evoluzione controllata                                           0.096721
# analfabeti                                                                              0.087685
# VEGETAZIONE_TIPO_Lariceto a megaforbie                                                  0.082800
# Name: PC5, dtype: float64
#
# Top features for PC3:
# VEGETAZIONE_TIPO_Lariceto dei campi di massi                                               0.349655
# VEGETAZIONE_TIPO_Abetina oligotrofica mesalpica                                            0.278692
# VEGETAZIONE_TIPO_Alneto di ontano verde                                                    0.267555
# VEGETAZIONE_TIPO_Querceto di rovere/roverella con orniello ed Erica cinerea                0.264974
# VEGETAZIONE_TIPO_Rimboschimento del piano subalpino                                        0.209160
# VEGETAZIONE_TIPO_Castagneto neutrofilo dell'Appennino e dei rilievi collinari interni\n    0.204351
# VEGETAZIONE_TIPO_Pineta di pino uncinato eretto                                            0.196604
# VEGETAZIONE_TIPO_Faggeta mesoxerofila                                                      0.196530
# VEGETAZIONE_TIPO_Acero-tiglio-frassineto di forra                                          0.179198
# VEGETAZIONE_TIPO_Querceto di rovere a Teucrium scorodonia                                  0.167605
# VEGETAZIONE_TIPO_Alneto di ontano nero                                                     0.167466
# VEGETAZIONE_TIPO_Faggeta mesotrofica                                                       0.154553
# VEGETAZIONE_TIPO_Lariceto pascolivo                                                        0.151114
# VEGETAZIONE_TIPO_Lariceto montano                                                          0.150538
# VEGETAZIONE_TIPO_Pecceta montana mesalpica                                                 0.146223
# VEGETAZIONE_TIPO_Robinia pseudoacacia                                                      0.134546
# VEGETAZIONE_TIPO_Querco-tiglieto                                                           0.128238
# VEGETAZIONE_TIPO_Abetina altimontana a megaforbie                                          0.123920
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                           0.118392
# VEGETAZIONE_TIPO_Querco-carpineto d'alta pianura ad elevate precipitazioni                 0.113502
# VEGETAZIONE_TIPO_Pineta di brughiera su morene e terrazzi fluvio-glaciali                  0.107267
# VEGETAZIONE_TIPO_Betuleto montano                                                          0.106939
# VEGETAZIONE_TIPO_Lariceto di greto                                                         0.104782
# VEGETAZIONE_TIPO_Abetina eutrofica                                                         0.092614
# VEGETAZIONE_TIPO_Arbusteto di Spartium junceum                                             0.090392
# analfabeti                                                                                 0.087629
# VEGETAZIONE_TIPO_Impianti indifferenziati                                                  0.086022
# VEGETAZIONE_TIPO_Orno-ostrieto delle Alpi Liguri e Marittime                               0.082760
# VEGETAZIONE_TIPO_Querceto xero-basifilo di roverella delle Alpi                            0.081287
# VEGETAZIONE_TIPO_Cerreta mista appenninica a Sesleria cylindrica                           0.080114
# Name: PC3, dtype: float64
#
# Top features for PC15:
# VEGETAZIONE_TIPO_Rimboschimento del piano montano                                                                  0.534175
# VEGETAZIONE_TIPO_Saliceto arbustivo ripario                                                                        0.437860
# VEGETAZIONE_TIPO_Corileto d'invasione                                                                              0.371151
# VEGETAZIONE_TIPO_Pineta di pino silvestre dei rilievi collinari interni                                            0.355977
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella con Erica arborea                                            0.206186
# VEGETAZIONE_TIPO_Faggeta appenninica a Physospermum cornubiense                                                    0.190138
# VEGETAZIONE_TIPO_Cerreta mesoxerofila                                                                              0.159713
# VEGETAZIONE_TIPO_Boscaglia rupestre pioniera                                                                       0.127208
# VEGETAZIONE_TIPO_Querceto di rovere a Physospermum cornubiense dei substrati silicatici dell'Appennino             0.107642
# VEGETAZIONE_TIPO_Querco-carpineto della bassa pianura                                                              0.106108
# VEGETAZIONE_TIPO_Castagneto neutrofilo dell'Appennino e dei rilievi collinari interni                              0.100473
# VEGETAZIONE_TIPO_Castagneto acidofilo a Physospermum cornubiense dell'Appennino e dei rilievi collinari interni    0.099313
# VEGETAZIONE_CATEGORIA_Rimboschimenti                                                                               0.093134
# VEGETAZIONE_TIPO_Faggeta eutrofica appenninica                                                                     0.091167
# analfabeti                                                                                                         0.087474
# VEGETAZIONE_TIPO_Impianti di conifere                                                                              0.067958
# VEGETAZIONE_TIPO_Pineta di pino marittimo                                                                          0.065575
# VEGETAZIONE_TIPO_Querceto di rovere a Physospermum cornubiense dei rilievi collinari interni                       0.065114
# VEGETAZIONE_TIPO_Orno-ostrieto dei rilievi collinari marnoso-arenacei                                              0.064443
# VEGETAZIONE_CATEGORIA_Lariceti e cembrete                                                                          0.061997
# VEGETAZIONE_TIPO_Impianti indifferenziati                                                                          0.061413
# VEGETAZIONE_TIPO_Impianti di latifoglie di pregio                                                                  0.060917
# VEGETAZIONE_TIPO_Querceto mesoxerofilo di roverella dei rilievi collinari interni e dell'Appennino                 0.058905
# VEGETAZIONE_TIPO_Arbusteto di Spartium junceum                                                                     0.057207
# VEGETAZIONE_TIPO_Alneto di ontano nero                                                                             0.053641
# VEGETAZIONE_TIPO_Boscaglie d'invasione                                                                             0.047083
# 25_49_diploma di tecnico superiore ITS o titolo di studio terziario di primo livello                               0.041599
# VEGETAZIONE_TIPO_Pioppeto di pioppo nero                                                                           0.039450
# VEGETAZIONE_TIPO_Pioppeto di pioppo bianco                                                                         0.036035
# 25_49_licenza di scuola media inferiore o di avviamento professionale                                              0.034902
# Name: PC15, dtype: float64
#
# Top features for PC6:
# VEGETAZIONE_TIPO_Faggeta eutrofica delle Alpi                                                                      0.331811
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris                                      0.302031
# VEGETAZIONE_TIPO_Pineta di brughiera su morene e terrazzi fluvio-glaciali                                          0.242976
# VEGETAZIONE_TIPO_Querco-tiglieto                                                                                   0.230148
# VEGETAZIONE_TIPO_Querceto mesoxerofilo di roverella delle Alpi                                                     0.228441
# VEGETAZIONE_TIPO_Lariceto pascolivo                                                                                0.226710
# VEGETAZIONE_TIPO_Abetina oligotrofica mesalpica                                                                    0.215216
# VEGETAZIONE_TIPO_Querceto di rovere/roverella con orniello ed Erica cinerea                                        0.193873
# VEGETAZIONE_TIPO_Pineta endalpica di greto di pino silvestre                                                       0.182568
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                                                                     0.170652
# VEGETAZIONE_INTERVENTO_Taglio a buche, a strisce, a fessura                                                        0.166892
# VEGETAZIONE_TIPO_Pecceta montana mesalpica                                                                         0.160248
# VEGETAZIONE_TIPO_Faggeta altimontana a megaforbie                                                                  0.151574
# VEGETAZIONE_TIPO_Lariceto a megaforbie                                                                             0.136531
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                                                   0.131308
# VEGETAZIONE_TIPO_Querceto di rovere a Potentilla alba                                                              0.131184
# VEGETAZIONE_TIPO_Cembreta xero-acidofila                                                                           0.127956
# VEGETAZIONE_TIPO_Cerreta mista appenninica a Sesleria cylindrica                                                   0.126454
# VEGETAZIONE_INTERVENTO_Ricostituzione boschiva, taglio fitosanitario o rinfoltimento                               0.124097
# VEGETAZIONE_TIPO_Pecceta subalpina                                                                                 0.123516
# VEGETAZIONE_TIPO_Pineta mesalpica basifila di pino silvestre                                                       0.112760
# VEGETAZIONE_TIPO_Alneto di ontano nero                                                                             0.107971
# VEGETAZIONE_TIPO_Querco-carpineto mesoxerofilo del Monferrato e/o Colline del Po                                   0.103206
# VEGETAZIONE_TIPO_Querco-carpineto della bassa pianura                                                              0.101939
# VEGETAZIONE_TIPO_Faggeta mesoxerofila                                                                              0.101662
# VEGETAZIONE_TIPO_Abetina eutrofica                                                                                 0.101156
# VEGETAZIONE_INTERVENTO_Gestione a ceduo composto                                                                   0.091614
# VEGETAZIONE_TIPO_Castagneto acidofilo a Physospermum cornubiense dell'Appennino e dei rilievi collinari interni    0.088853
# VEGETAZIONE_TIPO_Querceto xero-basifilo di roverella delle Alpi                                                    0.088575
# VEGETAZIONE_TIPO_Faggeta basifila pioniera                                                                         0.088363
# Name: PC6, dtype: float64
#
# Top features for PC4:
# VEGETAZIONE_TIPO_Pineta di pino uncinato eretto                                  0.421700
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris    0.287288
# VEGETAZIONE_TIPO_Querceto di rovere a Potentilla alba                            0.276146
# VEGETAZIONE_TIPO_?                                                               0.242826
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                                   0.209846
# VEGETAZIONE_TIPO_Pineta mesalpica acidofila di pino silvestre                    0.187604
# VEGETAZIONE_TIPO_Pineta mesalpica basifila di pino silvestre                     0.172167
# VEGETAZIONE_INTERVENTO_Diradamento e conversione                                 0.169770
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale                                 0.158889
# VEGETAZIONE_INTERVENTO_Formazione lineare                                        0.149991
# VEGETAZIONE_TIPO_Pecceta montana mesalpica                                       0.148084
# VEGETAZIONE_INTERVENTO_Ceduazione                                                0.146454
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                 0.141671
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale per collettivi                  0.141411
# VEGETAZIONE_INTERVENTO_Aree per cui non si prevede intervento                    0.139687
# VEGETAZIONE_TIPO_Cerreta mesofila                                                0.136565
# VEGETAZIONE_TIPO_Specie esotiche o naturalizzate                                 0.131005
# VEGETAZIONE_TIPO_Faggeta basifila pioniera                                       0.128110
# VEGETAZIONE_TIPO_Pecceta montana endalpica                                       0.121473
# VEGETAZIONE_TIPO_Abetina altimontana a megaforbie                                0.120966
# VEGETAZIONE_TIPO_Abetina eutrofica                                               0.119384
# VEGETAZIONE_TIPO_Lariceto a megaforbie                                           0.115513
# VEGETAZIONE_TIPO_Pineta endalpica mesoxerofila di pino silvestre                 0.113548
# VEGETAZIONE_TIPO_Faggeta mesoxerofila                                            0.109753
# VEGETAZIONE_TIPO_Pineta endalpica acidofila di pino silvestre                    0.109244
# VEGETAZIONE_TIPO_Betuleto montano                                                0.104924
# VEGETAZIONE_TIPO_Pineta endalpica basifila di pino silvestre                     0.100173
# VEGETAZIONE_TIPO_Lariceto montano                                                0.098562
# VEGETAZIONE_TIPO_Specie spontanee                                                0.091584
# analfabeti                                                                       0.087734
# Name: PC4, dtype: float64
#
# Top features for PC2:
# VEGETAZIONE_TIPO_Querceto di rovere/roverella con orniello ed Erica cinerea                0.485089
# VEGETAZIONE_TIPO_Faggeta eutrofica delle Alpi                                              0.279103
# VEGETAZIONE_TIPO_Lariceto pascolivo                                                        0.260871
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris              0.235312
# VEGETAZIONE_TIPO_Acero-tiglio-frassineto di forra                                          0.212371
# VEGETAZIONE_TIPO_Querco-tiglieto                                                           0.202583
# VEGETAZIONE_TIPO_Abetina oligotrofica mesalpica                                            0.174289
# VEGETAZIONE_TIPO_Querco-carpineto mesoxerofilo del Monferrato e/o Colline del Po           0.170046
# VEGETAZIONE_TIPO_Cerreta mesofila                                                          0.168613
# VEGETAZIONE_TIPO_Querceto di rovere a Teucrium scorodonia                                  0.160752
# VEGETAZIONE_TIPO_Castagneto da frutto                                                      0.158994
# VEGETAZIONE_TIPO_Faggeta basifila pioniera                                                 0.155563
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                           0.138327
# VEGETAZIONE_TIPO_Pineta mesalpica acidofila di pino silvestre                              0.136883
# VEGETAZIONE_TIPO_Pineta di pino montano prostrato                                          0.133785
# VEGETAZIONE_TIPO_Alneto di ontano bianco                                                   0.131314
# VEGETAZIONE_TIPO_Pineta endalpica basifila di pino silvestre                               0.128794
# VEGETAZIONE_TIPO_Betuleto montano                                                          0.119013
# VEGETAZIONE_TIPO_Pecceta subalpina                                                         0.116707
# VEGETAZIONE_TIPO_Pecceta montana mesalpica                                                 0.116582
# VEGETAZIONE_TIPO_Specie spontanee                                                          0.113543
# VEGETAZIONE_TIPO_Pineta di brughiera su morene e terrazzi fluvio-glaciali                  0.109054
# VEGETAZIONE_TIPO_Orno-ostrieto delle Alpi Liguri e Marittime                               0.099711
# VEGETAZIONE_TIPO_Pecceta montana endalpica                                                 0.095383
# VEGETAZIONE_TIPO_Castagneto neutrofilo dell'Appennino e dei rilievi collinari interni\n    0.088922
# analfabeti                                                                                 0.087459
# VEGETAZIONE_TIPO_Lariceto mesoxerofilo subalpino                                           0.085446
# VEGETAZIONE_TIPO_Querceto mesoxerofilo di roverella delle Alpi                             0.082492
# VEGETAZIONE_TIPO_Arbusteto appenninico ad Erica arborea\n                                  0.079473
# VEGETAZIONE_TIPO_Faggeta mesoxerofila                                                      0.072199
# Name: PC2, dtype: float64
#
# Top features for PC12:
# VEGETAZIONE_TIPO_Querceto di rovere a Potentilla alba                            0.356873
# VEGETAZIONE_TIPO_Specie esotiche o naturalizzate                                 0.322010
# VEGETAZIONE_INTERVENTO_Conversione attiva                                        0.291351
# VEGETAZIONE_TIPO_?                                                               0.261016
# VEGETAZIONE_TIPO_Lariceto a megaforbie                                           0.191710
# VEGETAZIONE_TIPO_Pecceta montana endalpica                                       0.189567
# VEGETAZIONE_TIPO_Pineta endalpica di greto di pino silvestre                     0.185815
# VEGETAZIONE_TIPO_Lariceto di greto                                               0.181321
# VEGETAZIONE_TIPO_Specie spontanee                                                0.164829
# VEGETAZIONE_TIPO_Pineta endalpica mesoxerofila di pino silvestre                 0.157212
# VEGETAZIONE_TIPO_Pineta di pino uncinato eretto                                  0.148936
# VEGETAZIONE_INTERVENTO_Tagli successivi adattati                                 0.136668
# VEGETAZIONE_INTERVENTO_Evoluzione controllata (senza gestione attiva)            0.135995
# VEGETAZIONE_TIPO_Faggeta mesoxerofila                                            0.133383
# VEGETAZIONE_INTERVENTO_Taglio a buche, a strisce, a fessura                      0.130737
# VEGETAZIONE_INTERVENTO_Gestione a ceduo composto                                 0.126267
# VEGETAZIONE_TIPO_Pecceta subalpina                                               0.125958
# VEGETAZIONE_INTERVENTO_Evoluzione naturale                                       0.118591
# VEGETAZIONE_TIPO_Faggeta altimontana a megaforbie                                0.118185
# VEGETAZIONE_TIPO_Cembreta xero-acidofila                                         0.117276
# VEGETAZIONE_INTERVENTO_Diradamento e conversione                                 0.116897
# VEGETAZIONE_TIPO_Faggeta basifila pioniera                                       0.113922
# VEGETAZIONE_TIPO_Rimboschimento del piano subalpino                              0.113578
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris    0.110037
# VEGETAZIONE_INTERVENTO_Ceduazione                                                0.103912
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                                   0.103377
# VEGETAZIONE_TIPO_Pineta endalpica acidofila di pino silvestre                    0.102848
# VEGETAZIONE_TIPO_Castagneto da frutto                                            0.102257
# analfabeti                                                                       0.087643
# VEGETAZIONE_TIPO_Querceto di rovere/roverella con orniello ed Erica cinerea      0.086537
# Name: PC12, dtype: float64
#
# Top features for PC10:
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale per collettivi                             0.504016
# VEGETAZIONE_INTERVENTO_Formazione lineare                                                   0.426128
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale                                            0.344764
# VEGETAZIONE_PRIORITA_Differibile - tra 11 e 15 anni                                         0.206074
# VEGETAZIONE_PRIORITA_Aree per cui non si prevede priorita' d'intervento                     0.165652
# VEGETAZIONE_TIPO_Pineta di pino uncinato eretto                                             0.146927
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris               0.143423
# VEGETAZIONE_INTERVENTO_Trasformazione                                                       0.140371
# VEGETAZIONE_PRIORITA_Nessuna                                                                0.137397
# VEGETAZIONE_TIPO_Faggeta mesotrofica                                                        0.133122
# VEGETAZIONE_INTERVENTO_Tagli successivi adattati                                            0.117520
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                            0.110941
# VEGETAZIONE_DESTINAZ_Categorie di uso del suolo per cui non e' prevista una destinazione    0.109012
# VEGETAZIONE_TIPO_Pineta di pino montano prostrato                                           0.106860
# VEGETAZIONE_DESTINAZ_Protettiva                                                             0.103586
# VEGETAZIONE_TIPO_Pecceta montana mesalpica                                                  0.091817
# VEGETAZIONE_INTERVENTO_Ceduazione                                                           0.090959
# VEGETAZIONE_ASSETTO_Ceduo a sterzo (ceduo disetaneo)                                        0.089631
# analfabeti                                                                                  0.087621
# VEGETAZIONE_PRIORITA_Nessun intervento                                                      0.086474
# VEGETAZIONE_PRIORITA_Breve termine - entro 5 anni                                           0.083957
# VEGETAZIONE_TIPO_Lariceto a megaforbie                                                      0.083738
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                                              0.083060
# VEGETAZIONE_TIPO_Acero-tiglio-frassineto di forra                                           0.082529
# VEGETAZIONE_PRIORITA_Medio termine - tra 6 e 10 anni                                        0.082056
# VEGETAZIONE_INTERVENTO_Evoluzione controllata                                               0.081908
# VEGETAZIONE_DESTINAZ_Mantenimento delle praterie di altitudine                              0.081128
# VEGETAZIONE_TIPO_Lariceto montano                                                           0.077044
# VEGETAZIONE_ASSETTO_Bosco di neoformazione (invasione)                                      0.076061
# VEGETAZIONE_TIPO_Pecceta montana endalpica                                                  0.075841
# Name: PC10, dtype: float64
#
# Top features for PC5:
# VEGETAZIONE_TIPO_Pineta di pino montano prostrato                                       0.390936
# VEGETAZIONE_INTERVENTO_Ricostituzione boschiva, taglio fitosanitario o rinfoltimento    0.345285
# VEGETAZIONE_TIPO_Pineta endalpica basifila di pino silvestre                            0.199455
# VEGETAZIONE_TIPO_Querceto mesoxerofilo di roverella delle Alpi                          0.199445
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                        0.198252
# VEGETAZIONE_TIPO_Abetina oligotrofica mesalpica                                         0.186243
# VEGETAZIONE_INTERVENTO_Taglio a buche, a strisce, a fessura                             0.173255
# VEGETAZIONE_TIPO_Cembreta xero-acidofila                                                0.170711
# VEGETAZIONE_TIPO_Alneto di ontano verde                                                 0.160328
# VEGETAZIONE_TIPO_Abetina altimontana a megaforbie                                       0.159724
# VEGETAZIONE_INTERVENTO_Evoluzione libera                                                0.158406
# VEGETAZIONE_TIPO_Rimboschimento del piano subalpino                                     0.154170
# VEGETAZIONE_INTERVENTO_Ceduazione                                                       0.143081
# VEGETAZIONE_TIPO_Pineta mesalpica basifila di pino silvestre                            0.136434
# VEGETAZIONE_TIPO_Specie esotiche o naturalizzate                                        0.133700
# VEGETAZIONE_TIPO_?                                                                      0.129834
# VEGETAZIONE_INTERVENTO_Gestione a ceduo composto                                        0.127236
# VEGETAZIONE_INTERVENTO_Diradamento e conversione                                        0.122380
# VEGETAZIONE_PRIORITA_Nessuna                                                            0.122322
# VEGETAZIONE_TIPO_Lariceto mesoxerofilo subalpino                                        0.118991
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale per collettivi                         0.117083
# VEGETAZIONE_TIPO_Alneto di ontano bianco                                                0.116771
# VEGETAZIONE_TIPO_Faggeta eutrofica delle Alpi                                           0.115916
# VEGETAZIONE_TIPO_Lariceto dei campi di massi                                            0.112283
# VEGETAZIONE_INTERVENTO_Evoluzione controllata (senza gestione attiva)                   0.108010
# VEGETAZIONE_INTERVENTO_Aree per cui non si prevede intervento                           0.107014
# VEGETAZIONE_TIPO_Pineta di brughiera su morene e terrazzi fluvio-glaciali               0.105899
# VEGETAZIONE_INTERVENTO_Evoluzione controllata                                           0.096721
# analfabeti                                                                              0.087685
# VEGETAZIONE_TIPO_Lariceto a megaforbie                                                  0.082800
# Name: PC5, dtype: float64
#
# Top features for PC3:
# VEGETAZIONE_TIPO_Lariceto dei campi di massi                                               0.349655
# VEGETAZIONE_TIPO_Abetina oligotrofica mesalpica                                            0.278692
# VEGETAZIONE_TIPO_Alneto di ontano verde                                                    0.267555
# VEGETAZIONE_TIPO_Querceto di rovere/roverella con orniello ed Erica cinerea                0.264974
# VEGETAZIONE_TIPO_Rimboschimento del piano subalpino                                        0.209160
# VEGETAZIONE_TIPO_Castagneto neutrofilo dell'Appennino e dei rilievi collinari interni\n    0.204351
# VEGETAZIONE_TIPO_Pineta di pino uncinato eretto                                            0.196604
# VEGETAZIONE_TIPO_Faggeta mesoxerofila                                                      0.196530
# VEGETAZIONE_TIPO_Acero-tiglio-frassineto di forra                                          0.179198
# VEGETAZIONE_TIPO_Querceto di rovere a Teucrium scorodonia                                  0.167605
# VEGETAZIONE_TIPO_Alneto di ontano nero                                                     0.167466
# VEGETAZIONE_TIPO_Faggeta mesotrofica                                                       0.154553
# VEGETAZIONE_TIPO_Lariceto pascolivo                                                        0.151114
# VEGETAZIONE_TIPO_Lariceto montano                                                          0.150538
# VEGETAZIONE_TIPO_Pecceta montana mesalpica                                                 0.146223
# VEGETAZIONE_TIPO_Robinia pseudoacacia                                                      0.134546
# VEGETAZIONE_TIPO_Querco-tiglieto                                                           0.128238
# VEGETAZIONE_TIPO_Abetina altimontana a megaforbie                                          0.123920
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                           0.118392
# VEGETAZIONE_TIPO_Querco-carpineto d'alta pianura ad elevate precipitazioni                 0.113502
# VEGETAZIONE_TIPO_Pineta di brughiera su morene e terrazzi fluvio-glaciali                  0.107267
# VEGETAZIONE_TIPO_Betuleto montano                                                          0.106939
# VEGETAZIONE_TIPO_Lariceto di greto                                                         0.104782
# VEGETAZIONE_TIPO_Abetina eutrofica                                                         0.092614
# VEGETAZIONE_TIPO_Arbusteto di Spartium junceum                                             0.090392
# analfabeti                                                                                 0.087629
# VEGETAZIONE_TIPO_Impianti indifferenziati                                                  0.086022
# VEGETAZIONE_TIPO_Orno-ostrieto delle Alpi Liguri e Marittime                               0.082760
# VEGETAZIONE_TIPO_Querceto xero-basifilo di roverella delle Alpi                            0.081287
# VEGETAZIONE_TIPO_Cerreta mista appenninica a Sesleria cylindrica                           0.080114
# Name: PC3, dtype: float64
#
# Top features for PC15:
# VEGETAZIONE_TIPO_Rimboschimento del piano montano                                                                  0.534175
# VEGETAZIONE_TIPO_Saliceto arbustivo ripario                                                                        0.437860
# VEGETAZIONE_TIPO_Corileto d'invasione                                                                              0.371151
# VEGETAZIONE_TIPO_Pineta di pino silvestre dei rilievi collinari interni                                            0.355977
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella con Erica arborea                                            0.206186
# VEGETAZIONE_TIPO_Faggeta appenninica a Physospermum cornubiense                                                    0.190138
# VEGETAZIONE_TIPO_Cerreta mesoxerofila                                                                              0.159713
# VEGETAZIONE_TIPO_Boscaglia rupestre pioniera                                                                       0.127208
# VEGETAZIONE_TIPO_Querceto di rovere a Physospermum cornubiense dei substrati silicatici dell'Appennino             0.107642
# VEGETAZIONE_TIPO_Querco-carpineto della bassa pianura                                                              0.106108
# VEGETAZIONE_TIPO_Castagneto neutrofilo dell'Appennino e dei rilievi collinari interni                              0.100473
# VEGETAZIONE_TIPO_Castagneto acidofilo a Physospermum cornubiense dell'Appennino e dei rilievi collinari interni    0.099313
# VEGETAZIONE_CATEGORIA_Rimboschimenti                                                                               0.093134
# VEGETAZIONE_TIPO_Faggeta eutrofica appenninica                                                                     0.091167
# analfabeti                                                                                                         0.087474
# VEGETAZIONE_TIPO_Impianti di conifere                                                                              0.067958
# VEGETAZIONE_TIPO_Pineta di pino marittimo                                                                          0.065575
# VEGETAZIONE_TIPO_Querceto di rovere a Physospermum cornubiense dei rilievi collinari interni                       0.065114
# VEGETAZIONE_TIPO_Orno-ostrieto dei rilievi collinari marnoso-arenacei                                              0.064443
# VEGETAZIONE_CATEGORIA_Lariceti e cembrete                                                                          0.061997
# VEGETAZIONE_TIPO_Impianti indifferenziati                                                                          0.061413
# VEGETAZIONE_TIPO_Impianti di latifoglie di pregio                                                                  0.060917
# VEGETAZIONE_TIPO_Querceto mesoxerofilo di roverella dei rilievi collinari interni e dell'Appennino                 0.058905
# VEGETAZIONE_TIPO_Arbusteto di Spartium junceum                                                                     0.057207
# VEGETAZIONE_TIPO_Alneto di ontano nero                                                                             0.053641
# VEGETAZIONE_TIPO_Boscaglie d'invasione                                                                             0.047083
# 25_49_diploma di tecnico superiore ITS o titolo di studio terziario di primo livello                               0.041599
# VEGETAZIONE_TIPO_Pioppeto di pioppo nero                                                                           0.039450
# VEGETAZIONE_TIPO_Pioppeto di pioppo bianco                                                                         0.036035
# 25_49_licenza di scuola media inferiore o di avviamento professionale                                              0.034902
# Name: PC15, dtype: float64
#
# Top features for PC6:
# VEGETAZIONE_TIPO_Faggeta eutrofica delle Alpi                                                                      0.331811
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris                                      0.302031
# VEGETAZIONE_TIPO_Pineta di brughiera su morene e terrazzi fluvio-glaciali                                          0.242976
# VEGETAZIONE_TIPO_Querco-tiglieto                                                                                   0.230148
# VEGETAZIONE_TIPO_Querceto mesoxerofilo di roverella delle Alpi                                                     0.228441
# VEGETAZIONE_TIPO_Lariceto pascolivo                                                                                0.226710
# VEGETAZIONE_TIPO_Abetina oligotrofica mesalpica                                                                    0.215216
# VEGETAZIONE_TIPO_Querceto di rovere/roverella con orniello ed Erica cinerea                                        0.193873
# VEGETAZIONE_TIPO_Pineta endalpica di greto di pino silvestre                                                       0.182568
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                                                                     0.170652
# VEGETAZIONE_INTERVENTO_Taglio a buche, a strisce, a fessura                                                        0.166892
# VEGETAZIONE_TIPO_Pecceta montana mesalpica                                                                         0.160248
# VEGETAZIONE_TIPO_Faggeta altimontana a megaforbie                                                                  0.151574
# VEGETAZIONE_TIPO_Lariceto a megaforbie                                                                             0.136531
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                                                   0.131308
# VEGETAZIONE_TIPO_Querceto di rovere a Potentilla alba                                                              0.131184
# VEGETAZIONE_TIPO_Cembreta xero-acidofila                                                                           0.127956
# VEGETAZIONE_TIPO_Cerreta mista appenninica a Sesleria cylindrica                                                   0.126454
# VEGETAZIONE_INTERVENTO_Ricostituzione boschiva, taglio fitosanitario o rinfoltimento                               0.124097
# VEGETAZIONE_TIPO_Pecceta subalpina                                                                                 0.123516
# VEGETAZIONE_TIPO_Pineta mesalpica basifila di pino silvestre                                                       0.112760
# VEGETAZIONE_TIPO_Alneto di ontano nero                                                                             0.107971
# VEGETAZIONE_TIPO_Querco-carpineto mesoxerofilo del Monferrato e/o Colline del Po                                   0.103206
# VEGETAZIONE_TIPO_Querco-carpineto della bassa pianura                                                              0.101939
# VEGETAZIONE_TIPO_Faggeta mesoxerofila                                                                              0.101662
# VEGETAZIONE_TIPO_Abetina eutrofica                                                                                 0.101156
# VEGETAZIONE_INTERVENTO_Gestione a ceduo composto                                                                   0.091614
# VEGETAZIONE_TIPO_Castagneto acidofilo a Physospermum cornubiense dell'Appennino e dei rilievi collinari interni    0.088853
# VEGETAZIONE_TIPO_Querceto xero-basifilo di roverella delle Alpi                                                    0.088575
# VEGETAZIONE_TIPO_Faggeta basifila pioniera                                                                         0.088363
# Name: PC6, dtype: float64

# %% [markdown]
# ---
