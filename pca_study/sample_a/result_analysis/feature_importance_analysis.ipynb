# %%
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
with open('/nfs/home/genovese/thesis-wildfire-genovese/pca_study/database/sample_a/trained_models/final_regression.pkl', 'rb') as f:
    r_model = pickle.load(f)

with open('/nfs/home/genovese/thesis-wildfire-genovese/pca_study/database/sample_a/trained_models/final_classification.pkl', 'rb') as f:
    c_model = pickle.load(f)

with open ('/nfs/home/genovese/thesis-wildfire-genovese/pca_study/database/sample_a/trained_models/pca.pkl', 'rb') as f:
    pca = pickle.load(f)
    
X_train = pd.read_csv('/nfs/home/genovese/thesis-wildfire-genovese/pca_study/database/sample_a/final_X_train_val.csv')
old_features = pd.read_csv('/nfs/home/genovese/thesis-wildfire-genovese/pca_study/database/sample_a/X_train_val.csv').columns

# %%
rf = pd.Series(r_model.feature_importances_, index=X_train.columns).sort_values(ascending=False)
cf = pd.Series(c_model.feature_importances_, index=X_train.columns).sort_values(ascending=False)

# %%
pd.concat([pd.Series(rf.index, name='regression'), pd.Series(cf.index, name='classification')], axis=1).to_latex()
# Out:
# "\\begin{tabular}{lll}\n\\toprule\n & regression & classification \\\\\n\\midrule\n0 & VEGETAZIONE_CATEGORIA_Castagneti & TOTALE_VEGETAZIONE \\\\\n1 & TOTALE_VEGETAZIONE & VEGETAZIONE_ASSETTO_Ceduo semplice con o senza matricine \\\\\n2 & TER_02 & VEGETAZIONE_PRIORITA_Nessuna \\\\\n3 & VEGETAZIONE_TIPO_Pioppeti & VEGETAZIONE_ASSETTO_Fustaia \\\\\n4 & Superficie a boschi & Reddito complessivo da 15000 a 26000 euro - Ammontare in euro \\\\\n5 & Reddito complessivo da 15000 a 26000 euro - Ammontare in euro & Reddito di spettanza dellimprenditore in contabilita semplificata - Ammontare in euro \\\\\n6 & TER_03 & Reddito complessivo da 55000 a 75000 euro - Ammontare in euro \\\\\n7 & terreni a riposo & VEGETAZIONE_ASSETTO_Ceduo composto (Fustaia sopra ceduo / ceduo sotto fustaia) \\\\\n8 & Superficie agricola utilizzata - ettari & 50_64_in altra condizione \\\\\n9 & piante industriali & VEGETAZIONE_CATEGORIA_Castagneti \\\\\n10 & cereali per la produzione di granella & AMB_02 \\\\\n11 & AMB_03 & SOC_01 \\\\\n12 & AMB_02 & SOC_02 \\\\\n13 & VEGETAZIONE_TIPO_Robinieto & TER_02 \\\\\n14 & totale ovini & SOC_04 \\\\\n15 & VEGETAZIONE_TIPO_Querceto di rovere a Potentilla alba & AMB_01 \\\\\n16 & Altra superficie rispetto a quella agricola utilizzata, a legna, a boschi e non utilizzata & SOC_03 \\\\\n17 & VEGETAZIONE_ASSETTO_Ceduo composto (Fustaia sopra ceduo / ceduo sotto fustaia) & TER_03 \\\\\n18 & SOC_01 & Superficie a boschi \\\\\n19 & Superficie per coltivazioni arboricole da legna & VEGETAZIONE_TIPO_Robinieto \\\\\n20 & patata & Superficie agricola utilizzata - ettari \\\\\n21 & Reddito complessivo da 55000 a 75000 euro - Ammontare in euro & cereali per la produzione di granella \\\\\n22 & SOC_02 & Superficie totale - ettari \\\\\n23 & AMB_01 & ECO_01 \\\\\n24 & Reddito di spettanza dellimprenditore in contabilita semplificata - Ammontare in euro & terreni a riposo \\\\\n25 & VEGETAZIONE_ASSETTO_Fustaia & totale ovini \\\\\n26 & SOC_04 & foraggere avvicendate \\\\\n27 & SOC_03 & totale alveari \\\\\n28 & VEGETAZIONE_PRIORITA_Nessuna & AMB_03 \\\\\n29 & VEGETAZIONE_ASSETTO_Ceduo semplice con o senza matricine & patata \\\\\n30 & ECO_01 & Altra superficie rispetto a quella agricola utilizzata, a legna, a boschi e non utilizzata \\\\\n31 & totale alveari & coltivazioni legnose agrarie \\\\\n32 & coltivazioni fruttifere & coltivazioni fruttifere \\\\\n33 & Superficie totale - ettari & piante industriali \\\\\n34 & vite & VEGETAZIONE_TIPO_Pioppeti \\\\\n35 & 50_64_in altra condizione & vite \\\\\n36 & foraggere avvicendate & Superficie per coltivazioni arboricole da legna \\\\\n37 & coltivazioni legnose agrarie & ortive protette in serra e tunnel accessibili all'uomo \\\\\n38 & ortive protette in serra e tunnel accessibili all'uomo & VEGETAZIONE_TIPO_Querceto di rovere a Potentilla alba \\\\\n\\bottomrule\n\\end{tabular}\n"

# %%
print(rf, '\n \n')
print(cf)
# Out:
# PC4     0.248101
# PC2     0.156257
# PC12    0.069254
# PC15    0.039607
# PC3     0.036664
# PC5     0.033282
# PC9     0.031906
# PC13    0.031047
# PC11    0.028723
# PC6     0.026778
# PC1     0.026333
# PC17    0.025848
# PC14    0.022710
# PC7     0.021694
# PC16    0.020348
# PC21    0.020314
# PC25    0.020156
# PC23    0.019362
# PC24    0.018812
# PC8     0.018102
# PC19    0.018069
# PC20    0.017829
# PC22    0.017733
# PC18    0.016774
# PC10    0.014297
# dtype: float64
#
#
# PC2     0.097508
# PC4     0.097134
# PC3     0.079074
# PC12    0.059490
# PC5     0.057459
# PC1     0.046864
# PC15    0.043661
# PC6     0.040513
# PC14    0.039761
# PC13    0.036760
# PC11    0.033070
# PC18    0.029231
# PC25    0.029148
# PC8     0.029055
# PC17    0.028746
# PC9     0.028472
# PC16    0.027996
# PC10    0.027259
# PC21    0.026278
# PC19    0.025874
# PC24    0.025467
# PC20    0.024903
# PC7     0.024151
# PC23    0.021075
# PC22    0.021052
# dtype: float64

# %%
pca_transform = pd.DataFrame(pca.components_, columns = [f'PC{n}' for n in range(1, len(old_features)+1)], index=old_features)
r_loadings = pca_transform.loc[:, [pc for pc in rf.index if 'PC' in pc]]
c_loadings = pca_transform.loc[:, [pc for pc in cf.index if 'PC' in pc]]

# %%
for col in pd.Series(list(r_loadings.columns)+list(c_loadings.columns)).unique():
    print(f"\nTop features for {col}:")
    top_features = r_loadings.loc[:, col].abs().sort_values(ascending=False).head(30)
    print(top_features)

for col in r_loadings.columns:
    print(f"\nTop features for {col}:")
    top_features = r_loadings.loc[:, col].abs().sort_values(ascending=False).head(30)
    print(top_features)
# Out:
# Top features for PC4:
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris                                        0.397406
# VEGETAZIONE_TIPO_Pineta di pino uncinato eretto                                                                      0.359682
# VEGETAZIONE_TIPO_Cembreta xero-acidofila                                                                             0.290597
# VEGETAZIONE_INTERVENTO_Gestione a ceduo composto                                                                     0.229924
# VEGETAZIONE_TIPO_?                                                                                                   0.219543
# VEGETAZIONE_TIPO_Pecceta montana endalpica                                                                           0.211425
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                                                                       0.203747
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale                                                                     0.198854
# VEGETAZIONE_INTERVENTO_Pascolamento di erbivori domestici o sfalcio delle praterie intercluse in ambiti forestali    0.183986
# VEGETAZIONE_TIPO_Faggeta oligotrofica                                                                                0.174305
# VEGETAZIONE_TIPO_Pineta endalpica di greto di pino silvestre                                                         0.153994
# VEGETAZIONE_TIPO_Faggeta altimontana a megaforbie                                                                    0.151306
# VEGETAZIONE_TIPO_Specie esotiche o naturalizzate                                                                     0.146243
# VEGETAZIONE_TIPO_Cerreta mesofila                                                                                    0.144662
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                                                     0.118019
# VEGETAZIONE_TIPO_Pineta mesalpica basifila di pino silvestre                                                         0.117273
# VEGETAZIONE_TIPO_Pineta di pino montano prostrato                                                                    0.115154
# VEGETAZIONE_TIPO_Betuleto montano                                                                                    0.114506
# VEGETAZIONE_TIPO_Abetina altimontana a megaforbie                                                                    0.110554
# VEGETAZIONE_TIPO_Pineta endalpica mesoxerofila di pino silvestre                                                     0.106546
# VEGETAZIONE_TIPO_Faggeta mesoxerofila                                                                                0.099434
# VEGETAZIONE_TIPO_Pineta di brughiera su morene e terrazzi fluvio-glaciali                                            0.092858
# analfabeti                                                                                                           0.087660
# VEGETAZIONE_TIPO_Pecceta subalpina                                                                                   0.087316
# VEGETAZIONE_TIPO_Lariceto montano                                                                                    0.085081
# VEGETAZIONE_TIPO_Pineta mesalpica acidofila di pino silvestre                                                        0.077856
# VEGETAZIONE_INTERVENTO_Taglio a buche, a strisce, a fessura                                                          0.077451
# VEGETAZIONE_TIPO_Castagneto acidofilo a Physospermum cornubiense dell'Appennino e dei rilievi collinari interni      0.075824
# VEGETAZIONE_INTERVENTO_Trasformazione                                                                                0.073693
# VEGETAZIONE_TIPO_Lariceto di greto                                                                                   0.071659
# Name: PC4, dtype: float64
#
# Top features for PC2:
# VEGETAZIONE_TIPO_Querceto di rovere/roverella con orniello ed Erica cinerea      0.492202
# VEGETAZIONE_TIPO_Faggeta eutrofica delle Alpi                                    0.376119
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris    0.215394
# VEGETAZIONE_TIPO_Lariceto pascolivo                                              0.195891
# VEGETAZIONE_TIPO_Cerreta mesofila                                                0.188544
# VEGETAZIONE_TIPO_Acero-tiglio-frassineto di forra                                0.187649
# VEGETAZIONE_TIPO_Betuleto montano                                                0.169702
# VEGETAZIONE_TIPO_Pineta mesalpica acidofila di pino silvestre                    0.161516
# VEGETAZIONE_TIPO_Faggeta oligotrofica                                            0.155321
# VEGETAZIONE_TIPO_Pecceta subalpina                                               0.150090
# VEGETAZIONE_TIPO_Lariceto dei campi di massi                                     0.148571
# VEGETAZIONE_TIPO_Querco-tiglieto                                                 0.140318
# VEGETAZIONE_TIPO_Querco-carpineto d'alta pianura ad elevate precipitazioni       0.130968
# VEGETAZIONE_TIPO_Alneto di ontano bianco                                         0.130538
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                                   0.130180
# VEGETAZIONE_TIPO_Betuleto planiziale di brughiera                                0.129012
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                 0.123979
# VEGETAZIONE_TIPO_Pineta di pino uncinato eretto                                  0.123700
# VEGETAZIONE_TIPO_Pineta di brughiera su morene e terrazzi fluvio-glaciali        0.116000
# VEGETAZIONE_TIPO_Lariceto montano                                                0.110257
# VEGETAZIONE_TIPO_Querceto di rovere a Teucrium scorodonia                        0.108219
# VEGETAZIONE_TIPO_Pioppeto d'invasione a pioppo tremolo                           0.107667
# VEGETAZIONE_TIPO_Pecceta montana endalpica                                       0.105431
# VEGETAZIONE_TIPO_Castagneto mesoneutrofilo a Salvia glutinosa delle Alpi         0.101251
# VEGETAZIONE_TIPO_Orno-ostrieto delle Alpi Liguri e Marittime                     0.097809
# VEGETAZIONE_TIPO_Querceto di rovere a Potentilla alba                            0.096245
# VEGETAZIONE_TIPO_Pineta di pino marittimo                                        0.090127
# analfabeti                                                                       0.087358
# VEGETAZIONE_TIPO_Pineta endalpica di greto di pino silvestre                     0.085130
# VEGETAZIONE_TIPO_Faggeta basifila pioniera                                       0.077550
# Name: PC2, dtype: float64
#
# Top features for PC12:
# VEGETAZIONE_TIPO_Lariceto di greto                                       0.342637
# VEGETAZIONE_INTERVENTO_Cure colturali                                    0.295175
# VEGETAZIONE_TIPO_Pineta endalpica acidofila di pino silvestre            0.294751
# VEGETAZIONE_TIPO_?                                                       0.265651
# VEGETAZIONE_TIPO_Specie spontanee                                        0.202338
# VEGETAZIONE_TIPO_Abetina endalpica                                       0.200689
# VEGETAZIONE_TIPO_Cembreta xero-acidofila                                 0.194677
# VEGETAZIONE_TIPO_Pineta endalpica di greto di pino silvestre             0.189056
# VEGETAZIONE_TIPO_Lariceto a megaforbie                                   0.175774
# VEGETAZIONE_TIPO_Faggeta basifila pioniera                               0.173994
# VEGETAZIONE_INTERVENTO_Aree per cui non si prevede intervento            0.172204
# VEGETAZIONE_INTERVENTO_Diradamento e conversione                         0.157419
# VEGETAZIONE_INTERVENTO_Taglio a buche, a strisce, a fessura              0.141167
# VEGETAZIONE_TIPO_Faggeta mesoxerofila                                    0.139051
# VEGETAZIONE_TIPO_Pecceta subalpina                                       0.136762
# VEGETAZIONE_TIPO_Querceto xero-basifilo di roverella delle Alpi          0.135167
# VEGETAZIONE_TIPO_Pineta di pino uncinato eretto                          0.134887
# VEGETAZIONE_TIPO_Pineta endalpica basifila di pino silvestre             0.120087
# VEGETAZIONE_TIPO_Pineta mesalpica acidofila di pino silvestre            0.111176
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                           0.110366
# VEGETAZIONE_INTERVENTO_Gestione a ceduo composto                         0.106272
# VEGETAZIONE_TIPO_Lariceto mesoxerofilo subalpino                         0.101996
# VEGETAZIONE_TIPO_Pineta endalpica mesoxerofila di pino silvestre         0.100523
# VEGETAZIONE_TIPO_Pineta di pino montano prostrato                        0.098022
# VEGETAZIONE_TIPO_Orno-ostrieto dei rilievi collinari marnoso-arenacei    0.094242
# VEGETAZIONE_TIPO_Rimboschimento dei piani planiziale e collinare         0.090982
# analfabeti                                                               0.087582
# VEGETAZIONE_TIPO_Faggeta altimontana a megaforbie                        0.086782
# VEGETAZIONE_INTERVENTO_Tagli successivi adattati                         0.085137
# VEGETAZIONE_INTERVENTO_Evoluzione naturale                               0.082814
# Name: PC12, dtype: float64
#
# Top features for PC15:
# VEGETAZIONE_TIPO_Cerreta mesoxerofila                                                                              0.604300
# VEGETAZIONE_TIPO_Arbusteto appenninico ad Erica arborea\n                                                          0.447223
# VEGETAZIONE_TIPO_Rimboschimento del piano montano                                                                  0.259836
# VEGETAZIONE_TIPO_Saliceto arbustivo ripario                                                                        0.250780
# VEGETAZIONE_TIPO_Corileto d'invasione                                                                              0.248780
# VEGETAZIONE_TIPO_Faggeta appenninica a Physospermum cornubiense                                                    0.202408
# VEGETAZIONE_TIPO_Querceto di rovere a Physospermum cornubiense dei substrati silicatici dell'Appennino             0.182097
# VEGETAZIONE_TIPO_Orno-ostrieto dell'Appennino calcareo-marnoso a Knautia drymeia                                   0.144530
# VEGETAZIONE_TIPO_Rimboschimento dei piani planiziale e collinare                                                   0.139144
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella con Erica arborea                                            0.129847
# VEGETAZIONE_TIPO_Castagneto neutrofilo dell'Appennino e dei rilievi collinari interni                              0.116830
# VEGETAZIONE_TIPO_Impianti di conifere                                                                              0.090250
# VEGETAZIONE_TIPO_Boscaglia rupestre pioniera                                                                       0.090159
# analfabeti                                                                                                         0.087362
# VEGETAZIONE_TIPO_Faggeta eutrofica appenninica                                                                     0.084984
# VEGETAZIONE_CATEGORIA_Lariceti e cembrete                                                                          0.069357
# VEGETAZIONE_CATEGORIA_Cerrete                                                                                      0.065558
# VEGETAZIONE_TIPO_Pineta di pino marittimo                                                                          0.064816
# VEGETAZIONE_TIPO_Boscaglie d'invasione                                                                             0.063236
# VEGETAZIONE_TIPO_Impianti di latifoglie di pregio                                                                  0.056352
# VEGETAZIONE_CATEGORIA_Rimboschimenti                                                                               0.049526
# VEGETAZIONE_TIPO_Querco-carpineto della bassa pianura                                                              0.049461
# VEGETAZIONE_TIPO_Pioppeto di pioppo bianco                                                                         0.049085
# VEGETAZIONE_CATEGORIA_Filare doppio                                                                                0.045268
# VEGETAZIONE_CATEGORIA_Castagneti                                                                                   0.045103
# VEGETAZIONE_TIPO_Alneto di ontano nero                                                                             0.043228
# VEGETAZIONE_TIPO_Querceto mesoxerofilo di roverella dei rilievi collinari interni e dell'Appennino                 0.042215
# VEGETAZIONE_TIPO_Impianti indifferenziati                                                                          0.042063
# VEGETAZIONE_CATEGORIA_Abetine                                                                                      0.041502
# VEGETAZIONE_TIPO_Castagneto acidofilo a Physospermum cornubiense dell'Appennino e dei rilievi collinari interni    0.040379
# Name: PC15, dtype: float64
#
# Top features for PC3:
# VEGETAZIONE_TIPO_Lariceto dei campi di massi                                               0.421753
# VEGETAZIONE_TIPO_Alneto di ontano verde                                                    0.311279
# VEGETAZIONE_TIPO_Querceto di rovere/roverella con orniello ed Erica cinerea                0.283247
# VEGETAZIONE_TIPO_Faggeta mesoxerofila                                                      0.202614
# VEGETAZIONE_TIPO_Pineta di pino uncinato eretto                                            0.195652
# VEGETAZIONE_TIPO_Abetina oligotrofica mesalpica                                            0.194506
# VEGETAZIONE_TIPO_Faggeta oligotrofica                                                      0.189815
# VEGETAZIONE_TIPO_Querco-carpineto d'alta pianura a basse precipitazioni                    0.177711
# VEGETAZIONE_TIPO_Pineta mesalpica acidofila di pino silvestre                              0.171737
# VEGETAZIONE_TIPO_Orno-ostrieto delle Alpi Liguri e Marittime                               0.155626
# VEGETAZIONE_TIPO_Rimboschimento del piano subalpino                                        0.149896
# VEGETAZIONE_TIPO_Querceto di rovere a Teucrium scorodonia                                  0.143526
# VEGETAZIONE_TIPO_Betuleto montano                                                          0.139188
# VEGETAZIONE_TIPO_Pineta di pino montano prostrato                                          0.129030
# VEGETAZIONE_TIPO_Querco-tiglieto                                                           0.121659
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                           0.116916
# VEGETAZIONE_TIPO_Lariceto pascolivo                                                        0.104983
# VEGETAZIONE_TIPO_Cerreta mista appenninica a Sesleria cylindrica                           0.102251
# VEGETAZIONE_TIPO_Impianti di conifere                                                      0.101194
# VEGETAZIONE_TIPO_Pineta endalpica basifila di pino silvestre                               0.100697
# VEGETAZIONE_TIPO_Lariceto di greto                                                         0.100323
# VEGETAZIONE_TIPO_Alneto di ontano bianco                                                   0.097537
# VEGETAZIONE_TIPO_Acero-tiglio-frassineto di forra                                          0.096213
# VEGETAZIONE_TIPO_Pineta di brughiera su morene e terrazzi fluvio-glaciali                  0.095641
# VEGETAZIONE_TIPO_Arbusteto di Spartium junceum                                             0.090482
# VEGETAZIONE_TIPO_Alneto di ontano nero                                                     0.090325
# analfabeti                                                                                 0.087528
# VEGETAZIONE_TIPO_Abetina eutrofica                                                         0.087428
# VEGETAZIONE_TIPO_Castagneto neutrofilo dell'Appennino e dei rilievi collinari interni\n    0.087002
# VEGETAZIONE_TIPO_Castagneto da frutto                                                      0.085059
# Name: PC3, dtype: float64
#
# Top features for PC5:
# VEGETAZIONE_TIPO_Pineta di pino montano prostrato                                                                    0.266708
# VEGETAZIONE_TIPO_Lariceto a megaforbie                                                                               0.235304
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                                                                       0.230833
# VEGETAZIONE_INTERVENTO_Tagli successivi adattati                                                                     0.226976
# VEGETAZIONE_TIPO_Abetina eutrofica                                                                                   0.221802
# VEGETAZIONE_TIPO_Querceto mesoxerofilo di roverella delle Alpi                                                       0.208727
# VEGETAZIONE_INTERVENTO_Ceduazione                                                                                    0.196065
# VEGETAZIONE_INTERVENTO_Trasformazione                                                                                0.195213
# VEGETAZIONE_TIPO_Abetina oligotrofica mesalpica                                                                      0.192937
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                                                     0.192175
# VEGETAZIONE_INTERVENTO_Evoluzione controllata (senza gestione attiva)                                                0.188309
# VEGETAZIONE_INTERVENTO_Pascolamento di erbivori domestici o sfalcio delle praterie intercluse in ambiti forestali    0.181478
# VEGETAZIONE_INTERVENTO_Conversione attiva                                                                            0.179289
# VEGETAZIONE_TIPO_Alneto di ontano verde                                                                              0.174151
# VEGETAZIONE_TIPO_Querceto xero-basifilo di roverella delle Alpi                                                      0.156276
# VEGETAZIONE_TIPO_Rimboschimento del piano subalpino                                                                  0.150492
# VEGETAZIONE_TIPO_Abetina endalpica                                                                                   0.142070
# VEGETAZIONE_TIPO_Faggeta eutrofica delle Alpi                                                                        0.125513
# VEGETAZIONE_TIPO_?                                                                                                   0.124690
# VEGETAZIONE_TIPO_Specie spontanee                                                                                    0.121804
# VEGETAZIONE_PRIORITA_Breve termine - entro 5 anni                                                                    0.120878
# VEGETAZIONE_TIPO_Lariceto dei campi di massi                                                                         0.116342
# VEGETAZIONE_INTERVENTO_Diradamento                                                                                   0.112542
# VEGETAZIONE_TIPO_Alneto di ontano bianco                                                                             0.106132
# VEGETAZIONE_INTERVENTO_Taglio a buche, a strisce, a fessura                                                          0.105526
# VEGETAZIONE_TIPO_Pineta di pino uncinato eretto                                                                      0.105305
# VEGETAZIONE_INTERVENTO_Aree per cui non si prevede intervento                                                        0.105138
# VEGETAZIONE_INTERVENTO_Gestione a ceduo composto                                                                     0.103835
# VEGETAZIONE_TIPO_Castagneto mesoneutrofilo a Salvia glutinosa delle Alpi                                             0.100293
# VEGETAZIONE_TIPO_Abetina altimontana a megaforbie                                                                    0.099123
# Name: PC5, dtype: float64
#
# Top features for PC9:
# VEGETAZIONE_TIPO_Querco-carpineto della bassa pianura                                                              0.423885
# VEGETAZIONE_TIPO_Boscaglia rupestre pioniera                                                                       0.287054
# VEGETAZIONE_TIPO_Rimboschimento del piano montano                                                                  0.286216
# VEGETAZIONE_TIPO_Acero-tiglio-frassineto d'invasione                                                               0.281498
# VEGETAZIONE_TIPO_Castagneto neutrofilo dell'Appennino e dei rilievi collinari interni                              0.256521
# VEGETAZIONE_TIPO_Arbusteto di Spartium junceum                                                                     0.231343
# VEGETAZIONE_TIPO_Rimboschimento dei piani planiziale e collinare                                                   0.209565
# VEGETAZIONE_TIPO_Impianti di conifere                                                                              0.188677
# VEGETAZIONE_TIPO_Cerreta mesoxerofila                                                                              0.178949
# VEGETAZIONE_TIPO_Cerreta mista appenninica a Sesleria cylindrica                                                   0.165374
# VEGETAZIONE_TIPO_Faggeta appenninica a Physospermum cornubiense                                                    0.163477
# VEGETAZIONE_TIPO_Arbusteto appenninico ad Erica arborea\n                                                          0.151796
# VEGETAZIONE_TIPO_Querco-carpineto d'alta pianura ad elevate precipitazioni                                         0.151786
# VEGETAZIONE_TIPO_Pioppeti                                                                                          0.142598
# VEGETAZIONE_TIPO_Querceto misto d'impluvio dei rilievi collinari interni                                           0.141036
# VEGETAZIONE_TIPO_Orno-ostrieto dell'Appennino calcareo-marnoso a Knautia drymeia                                   0.139538
# VEGETAZIONE_TIPO_Faggeta eutrofica appenninica                                                                     0.125522
# VEGETAZIONE_TIPO_Cerreta acidofila                                                                                 0.113259
# VEGETAZIONE_TIPO_Pioppeto d'invasione a pioppo tremolo                                                             0.110306
# VEGETAZIONE_CATEGORIA_Filare doppio                                                                                0.107251
# VEGETAZIONE_TIPO_Impianti di latifoglie di pregio                                                                  0.103031
# VEGETAZIONE_TIPO_Querco-carpineto d'alta pianura a basse precipitazioni                                            0.096747
# VEGETAZIONE_TIPO_Pineta di pino silvestre dei rilievi collinari interni                                            0.093640
# VEGETAZIONE_TIPO_Saliceto di salice bianco                                                                         0.090771
# analfabeti                                                                                                         0.084065
# VEGETAZIONE_TIPO_Querceto di rovere a Physospermum cornubiense dei substrati silicatici dell'Appennino             0.083372
# VEGETAZIONE_TIPO_Castagneto acidofilo a Physospermum cornubiense dell'Appennino e dei rilievi collinari interni    0.080078
# VEGETAZIONE_TIPO_Pioppeto di pioppo bianco                                                                         0.069385
# VEGETAZIONE_CATEGORIA_Pinete di pino montano                                                                       0.062381
# VEGETAZIONE_CATEGORIA_Abetine                                                                                      0.060541
# Name: PC9, dtype: float64
#
# Top features for PC13:
# VEGETAZIONE_TIPO_Pineta endalpica di greto di pino silvestre                                                         0.331077
# VEGETAZIONE_INTERVENTO_Aree per cui non si prevede intervento                                                        0.247408
# VEGETAZIONE_INTERVENTO_Ceduazione                                                                                    0.245675
# VEGETAZIONE_TIPO_Pecceta montana endalpica                                                                           0.232768
# VEGETAZIONE_TIPO_Robinia pseudoacacia                                                                                0.208222
# VEGETAZIONE_TIPO_Querceto xero-basifilo di roverella delle Alpi                                                      0.205905
# VEGETAZIONE_INTERVENTO_Evoluzione naturale                                                                           0.201224
# VEGETAZIONE_INTERVENTO_Gestione a ceduo composto                                                                     0.179807
# VEGETAZIONE_INTERVENTO_Formazione lineare                                                                            0.159050
# VEGETAZIONE_TIPO_Pineta endalpica basifila di pino silvestre                                                         0.155845
# VEGETAZIONE_INTERVENTO_Pascolamento di erbivori domestici o sfalcio delle praterie intercluse in ambiti forestali    0.148629
# VEGETAZIONE_INTERVENTO_Diradamento                                                                                   0.147982
# VEGETAZIONE_INTERVENTO_Taglio a buche, a strisce, a fessura                                                          0.146492
# VEGETAZIONE_INTERVENTO_Conversione attiva                                                                            0.138070
# VEGETAZIONE_TIPO_Pineta mesalpica acidofila di pino silvestre                                                        0.136990
# VEGETAZIONE_TIPO_Querceto di rovere a Potentilla alba                                                                0.131917
# VEGETAZIONE_INTERVENTO_Ricostituzione boschiva, taglio fitosanitario o rinfoltimento                                 0.131805
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                                                                       0.130271
# VEGETAZIONE_TIPO_Pineta di pino montano prostrato                                                                    0.127616
# VEGETAZIONE_TIPO_Castagneto mesoneutrofilo a Salvia glutinosa delle Alpi                                             0.127261
# VEGETAZIONE_INTERVENTO_Diradamento e conversione                                                                     0.122909
# VEGETAZIONE_TIPO_Querceto mesoxerofilo di roverella delle Alpi                                                       0.122151
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris                                        0.119656
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                                                     0.110259
# VEGETAZIONE_INTERVENTO_Cure colturali                                                                                0.108060
# VEGETAZIONE_TIPO_Cembreta xero-acidofila                                                                             0.094837
# VEGETAZIONE_TIPO_Lariceto a megaforbie                                                                               0.094834
# VEGETAZIONE_TIPO_Faggeta oligotrofica                                                                                0.091312
# VEGETAZIONE_TIPO_Faggeta mesotrofica                                                                                 0.090843
# VEGETAZIONE_DESTINAZ_Categorie di uso del suolo per cui non e' prevista una destinazione                             0.088822
# Name: PC13, dtype: float64
#
# Top features for PC11:
# VEGETAZIONE_TIPO_Pecceta subalpina                                               0.447400
# VEGETAZIONE_TIPO_Specie spontanee                                                0.289963
# VEGETAZIONE_INTERVENTO_Evoluzione controllata (senza gestione attiva)            0.286259
# VEGETAZIONE_INTERVENTO_Taglio a buche, a strisce, a fessura                      0.219261
# VEGETAZIONE_TIPO_Pecceta montana endalpica                                       0.203539
# VEGETAZIONE_TIPO_Pineta endalpica acidofila di pino silvestre                    0.200040
# VEGETAZIONE_TIPO_Specie esotiche o naturalizzate                                 0.191213
# VEGETAZIONE_TIPO_Abetina altimontana a megaforbie                                0.162146
# VEGETAZIONE_TIPO_Pineta endalpica di greto di pino silvestre                     0.156200
# VEGETAZIONE_INTERVENTO_Diradamento                                               0.151826
# VEGETAZIONE_TIPO_Robinia pseudoacacia                                            0.138755
# VEGETAZIONE_INTERVENTO_Evoluzione naturale                                       0.137475
# VEGETAZIONE_TIPO_?                                                               0.135332
# VEGETAZIONE_TIPO_Rimboschimento del piano subalpino                              0.120570
# VEGETAZIONE_TIPO_Orno-ostrieto delle Alpi Liguri e Marittime                     0.119950
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                 0.113035
# VEGETAZIONE_INTERVENTO_Conversione attiva                                        0.108400
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris    0.108394
# VEGETAZIONE_TIPO_Querceto misto d'impluvio dei rilievi collinari interni         0.107292
# VEGETAZIONE_TIPO_Querceto di rovere a Potentilla alba                            0.105719
# VEGETAZIONE_TIPO_Rimboschimento del piano montano                                0.101501
# VEGETAZIONE_TIPO_Lariceto a megaforbie                                           0.100555
# VEGETAZIONE_TIPO_Abetina endalpica                                               0.097615
# VEGETAZIONE_TIPO_Querceto xero-basifilo di roverella delle Alpi                  0.095973
# VEGETAZIONE_TIPO_Lariceto mesoxerofilo subalpino                                 0.095888
# VEGETAZIONE_TIPO_Pineta di pino silvestre dei rilievi collinari interni          0.091539
# VEGETAZIONE_TIPO_Pineta mesalpica basifila di pino silvestre                     0.089018
# analfabeti                                                                       0.087367
# VEGETAZIONE_TIPO_Lariceto pascolivo                                              0.084685
# VEGETAZIONE_INTERVENTO_Cure colturali                                            0.084511
# Name: PC11, dtype: float64
#
# Top features for PC6:
# VEGETAZIONE_TIPO_Faggeta eutrofica delle Alpi                                           0.364448
# VEGETAZIONE_TIPO_Querceto mesoxerofilo di roverella delle Alpi                          0.302996
# VEGETAZIONE_TIPO_Querceto di rovere/roverella con orniello ed Erica cinerea             0.283199
# VEGETAZIONE_TIPO_Pineta di brughiera su morene e terrazzi fluvio-glaciali               0.238880
# VEGETAZIONE_TIPO_Querco-tiglieto                                                        0.223109
# VEGETAZIONE_TIPO_Pineta di pino uncinato eretto                                         0.185406
# VEGETAZIONE_TIPO_Abetina oligotrofica mesalpica                                         0.182789
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris           0.172000
# VEGETAZIONE_TIPO_Faggeta mesoxerofila                                                   0.164224
# VEGETAZIONE_TIPO_Pineta endalpica basifila di pino silvestre                            0.159574
# VEGETAZIONE_TIPO_Specie spontanee                                                       0.155647
# VEGETAZIONE_TIPO_Lariceto pascolivo                                                     0.154646
# VEGETAZIONE_TIPO_Lariceto a megaforbie                                                  0.150683
# VEGETAZIONE_TIPO_Querceto di rovere a Potentilla alba                                   0.148513
# VEGETAZIONE_TIPO_Cerreta mista appenninica a Sesleria cylindrica                        0.143013
# VEGETAZIONE_TIPO_Faggeta mesotrofica                                                    0.131016
# VEGETAZIONE_TIPO_Abetina endalpica                                                      0.127997
# VEGETAZIONE_TIPO_Abetina eutrofica                                                      0.127989
# VEGETAZIONE_TIPO_Pineta mesalpica acidofila di pino silvestre                           0.114813
# VEGETAZIONE_INTERVENTO_Diradamento e conversione                                        0.112716
# VEGETAZIONE_INTERVENTO_Ceduazione                                                       0.110661
# VEGETAZIONE_TIPO_Betuleto montano                                                       0.107777
# VEGETAZIONE_TIPO_Rimboschimento del piano subalpino                                     0.106913
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                                          0.104157
# VEGETAZIONE_TIPO_Pecceta montana mesalpica                                              0.101587
# VEGETAZIONE_INTERVENTO_Ricostituzione boschiva, taglio fitosanitario o rinfoltimento    0.096750
# VEGETAZIONE_TIPO_Pineta mesalpica basifila di pino silvestre                            0.095591
# VEGETAZIONE_TIPO_Castagneto mesoneutrofilo a Salvia glutinosa delle Alpi                0.094703
# VEGETAZIONE_TIPO_Querco-carpineto della bassa pianura                                   0.091972
# analfabeti                                                                              0.086915
# Name: PC6, dtype: float64
#
# Top features for PC1:
# VEGETAZIONE_TIPO_Orno-ostrieto dell'Appennino calcareo-marnoso a Knautia drymeia                                   0.429980
# VEGETAZIONE_TIPO_Castagneto acidofilo a Physospermum cornubiense dell'Appennino e dei rilievi collinari interni    0.426008
# VEGETAZIONE_TIPO_Rimboschimento del piano montano                                                                  0.354171
# VEGETAZIONE_TIPO_Pineta di pino marittimo                                                                          0.287685
# VEGETAZIONE_TIPO_Boscaglie d'invasione                                                                             0.236371
# VEGETAZIONE_TIPO_Querceto mesoxerofilo di roverella dei rilievi collinari interni e dell'Appennino                 0.226828
# VEGETAZIONE_CATEGORIA_Filare doppio                                                                                0.195247
# VEGETAZIONE_TIPO_Impianti di conifere                                                                              0.171691
# VEGETAZIONE_TIPO_Boscaglia rupestre pioniera                                                                       0.163867
# VEGETAZIONE_TIPO_Arbusteto appenninico ad Erica arborea\n                                                          0.155087
# VEGETAZIONE_TIPO_Querco-carpineto della bassa pianura                                                              0.151193
# VEGETAZIONE_TIPO_Arbusteto di Spartium junceum                                                                     0.144066
# VEGETAZIONE_TIPO_Orno-ostrieto dei rilievi collinari marnoso-arenacei                                              0.123032
# VEGETAZIONE_TIPO_Impianti indifferenziati                                                                          0.111416
# VEGETAZIONE_TIPO_Impianti di latifoglie di pregio                                                                  0.096757
# VEGETAZIONE_TIPO_Rimboschimento dei piani planiziale e collinare                                                   0.090741
# VEGETAZIONE_TIPO_Castagneto neutrofilo dell'Appennino e dei rilievi collinari interni                              0.089901
# VEGETAZIONE_CATEGORIA_Pinete di pino montano                                                                       0.088721
# VEGETAZIONE_TIPO_Pioppeto di pioppo bianco                                                                         0.087748
# analfabeti                                                                                                         0.086984
# VEGETAZIONE_CATEGORIA_Alneti planiziali e montani                                                                  0.079043
# VEGETAZIONE_TIPO_Robinieto                                                                                         0.073240
# VEGETAZIONE_TIPO_Cerreta mesoxerofila                                                                              0.071165
# VEGETAZIONE_CATEGORIA_Abetine                                                                                      0.067512
# VEGETAZIONE_TIPO_Saliceto di salice bianco                                                                         0.066564
# VEGETAZIONE_CATEGORIA_Querco-carpineti                                                                             0.065094
# VEGETAZIONE_TIPO_Arbusteto mesoxerofilo di Prunus spinosa e Cornus sanguinea                                       0.062947
# VEGETAZIONE_CATEGORIA_Filare singolo                                                                               0.058992
# VEGETAZIONE_TIPO_Cerreta acidofila                                                                                 0.058392
# VEGETAZIONE_TIPO_Orno-ostrieto delle Alpi Liguri e Marittime                                                       0.057360
# Name: PC1, dtype: float64
#
# Top features for PC17:
# VEGETAZIONE_PRIORITA_Breve termine - entro 5 anni                                                                    0.433439
# VEGETAZIONE_DESTINAZ_Categorie di uso del suolo per cui non e' prevista una destinazione                             0.306430
# VEGETAZIONE_PRIORITA_Nessun intervento                                                                               0.280151
# VEGETAZIONE_ASSETTO_Ceduo in conversione                                                                             0.243333
# VEGETAZIONE_ASSETTO_Bosco di neoformazione (invasione)                                                               0.219322
# VEGETAZIONE_DESTINAZ_Fruizione                                                                                       0.219215
# VEGETAZIONE_DESTINAZ_Mantenimento delle praterie di altitudine                                                       0.216261
# VEGETAZIONE_INTERVENTO_Pascolamento di erbivori domestici o sfalcio delle praterie intercluse in ambiti forestali    0.214482
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale per collettivi                                                      0.203640
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale                                                                     0.144600
# VEGETAZIONE_ASSETTO_Categorie di uso del suolo per cui non e' descritto un assetto evolutivo                         0.139610
# VEGETAZIONE_INTERVENTO_Conversione attiva                                                                            0.128861
# VEGETAZIONE_INTERVENTO_Ricostituzione boschiva, taglio fitosanitario o rinfoltimento                                 0.126697
# VEGETAZIONE_DESTINAZ_Siepe arbustiva                                                                                 0.122508
# VEGETAZIONE_INTERVENTO_Trasformazione                                                                                0.121032
# VEGETAZIONE_PRIORITA_Nessuna                                                                                         0.119034
# VEGETAZIONE_INTERVENTO_Taglio a buche, a strisce, a fessura                                                          0.118257
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                                                                       0.117318
# VEGETAZIONE_ASSETTO_Ceduo semplice con o senza matricine                                                             0.112676
# VEGETAZIONE_TIPO_Pineta endalpica di greto di pino silvestre                                                         0.100371
# VEGETAZIONE_TIPO_Pecceta montana endalpica                                                                           0.095280
# VEGETAZIONE_INTERVENTO_Ceduazione                                                                                    0.094010
# VEGETAZIONE_DESTINAZ_Produttiva                                                                                      0.093292
# VEGETAZIONE_TIPO_Cembreta xero-acidofila                                                                             0.089745
# VEGETAZIONE_TIPO_Querceto misto d'impluvio dei rilievi collinari interni                                             0.089465
# analfabeti                                                                                                           0.087569
# VEGETAZIONE_PRIORITA_Medio termine - tra 6 e 10 anni                                                                 0.084686
# VEGETAZIONE_TIPO_Rimboschimento del piano montano                                                                    0.083215
# VEGETAZIONE_TIPO_Pineta di pino silvestre dei rilievi collinari interni                                              0.082111
# VEGETAZIONE_TIPO_Pineta endalpica acidofila di pino silvestre                                                        0.074673
# Name: PC17, dtype: float64
#
# Top features for PC14:
# VEGETAZIONE_INTERVENTO_Diradamento e conversione                                                          0.492891
# VEGETAZIONE_INTERVENTO_Evoluzione controllata (senza gestione attiva)                                     0.262476
# VEGETAZIONE_TIPO_Pecceta montana endalpica                                                                0.238373
# VEGETAZIONE_TIPO_Specie spontanee                                                                         0.207565
# VEGETAZIONE_TIPO_Pineta endalpica di greto di pino silvestre                                              0.205851
# VEGETAZIONE_TIPO_Querceto di rovere a Potentilla alba                                                     0.195717
# VEGETAZIONE_INTERVENTO_Ricostituzione boschiva, taglio fitosanitario o rinfoltimento                      0.179503
# VEGETAZIONE_TIPO_Specie esotiche o naturalizzate                                                          0.178483
# VEGETAZIONE_INTERVENTO_Aree per cui non si prevede intervento                                             0.170856
# VEGETAZIONE_TIPO_Cembreta xero-acidofila                                                                  0.147649
# VEGETAZIONE_TIPO_Pineta endalpica acidofila di pino silvestre                                             0.147203
# VEGETAZIONE_INTERVENTO_Trasformazione                                                                     0.140278
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale                                                          0.139385
# VEGETAZIONE_TIPO_Abetina oligotrofica mesalpica                                                           0.137638
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                                                            0.136127
# VEGETAZIONE_TIPO_Pineta di pino montano prostrato                                                         0.123035
# VEGETAZIONE_TIPO_?                                                                                        0.122010
# VEGETAZIONE_TIPO_Pineta di brughiera su morene e terrazzi fluvio-glaciali                                 0.121682
# VEGETAZIONE_TIPO_Robinia pseudoacacia                                                                     0.119456
# VEGETAZIONE_TIPO_Pineta endalpica basifila di pino silvestre                                              0.108685
# VEGETAZIONE_INTERVENTO_Gestione a ceduo composto                                                          0.092329
# VEGETAZIONE_TIPO_Abetina endalpica                                                                        0.088600
# VEGETAZIONE_TIPO_Lariceto a megaforbie                                                                    0.088044
# analfabeti                                                                                                0.087467
# VEGETAZIONE_TIPO_Abetina altimontana a megaforbie                                                         0.086928
# VEGETAZIONE_TIPO_Querceto di rovere a Physospermum cornubiense dei substrati silicatici dell'Appennino    0.086664
# VEGETAZIONE_TIPO_Lariceto mesoxerofilo subalpino                                                          0.082824
# VEGETAZIONE_TIPO_Boscaglia rupestre pioniera                                                              0.082526
# VEGETAZIONE_DESTINAZ_Categorie di uso del suolo per cui non e' prevista una destinazione                  0.076896
# VEGETAZIONE_TIPO_Pineta mesalpica acidofila di pino silvestre                                             0.073094
# Name: PC14, dtype: float64
#
# Top features for PC7:
# VEGETAZIONE_DESTINAZ_Filare con arbusti o siepe arbustiva                                       0.569538
# VEGETAZIONE_ASSETTO_Categorie di uso del suolo per cui non e' descritto un assetto evolutivo    0.195210
# VEGETAZIONE_TIPO_Betuleto montano                                                               0.175845
# VEGETAZIONE_DESTINAZ_Filare                                                                     0.146215
# VEGETAZIONE_TIPO_Castagneto neutrofilo dell'Appennino e dei rilievi collinari interni           0.144916
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris                   0.139621
# VEGETAZIONE_TIPO_Faggeta eutrofica delle Alpi                                                   0.137598
# VEGETAZIONE_TIPO_Lariceto dei campi di massi                                                    0.137531
# VEGETAZIONE_TIPO_Pineta endalpica mesoxerofila di pino silvestre                                0.136037
# VEGETAZIONE_TIPO_Cerreta mesofila                                                               0.135958
# VEGETAZIONE_DESTINAZ_Evoluzione libera senza specifica destinazione (superfici forestali)       0.134928
# VEGETAZIONE_ASSETTO_Bosco di neoformazione (invasione)                                          0.134502
# VEGETAZIONE_TIPO_Castagneto da frutto                                                           0.133133
# VEGETAZIONE_DESTINAZ_Fruizione                                                                  0.129272
# VEGETAZIONE_INTERVENTO_Cure colturali                                                           0.128121
# VEGETAZIONE_INTERVENTO_Ricostituzione boschiva, taglio fitosanitario o rinfoltimento            0.124839
# VEGETAZIONE_TIPO_Querco-carpineto d'alta pianura a basse precipitazioni                         0.120618
# VEGETAZIONE_TIPO_Acero-tiglio-frassineto di forra                                               0.115106
# VEGETAZIONE_TIPO_Acero-tiglio-frassineto d'invasione                                            0.110059
# VEGETAZIONE_DESTINAZ_Produttiva                                                                 0.107075
# VEGETAZIONE_TIPO_Castagneto acidofilo a Teucrium scorodonia delle Alpi                          0.103947
# VEGETAZIONE_TIPO_Arbusteto appenninico ad Erica arborea\n                                       0.102313
# VEGETAZIONE_TIPO_Pecceta montana endalpica                                                      0.100395
# VEGETAZIONE_TIPO_Querco-carpineto della bassa pianura                                           0.099831
# VEGETAZIONE_TIPO_Pineta di pino marittimo                                                       0.099390
# VEGETAZIONE_TIPO_Pecceta subalpina                                                              0.098000
# VEGETAZIONE_TIPO_Lariceto montano                                                               0.095776
# VEGETAZIONE_TIPO_Betuleto planiziale di brughiera                                               0.093218
# VEGETAZIONE_TIPO_Pineta endalpica basifila di pino silvestre                                    0.091486
# VEGETAZIONE_TIPO_Lariceto pascolivo                                                             0.091084
# Name: PC7, dtype: float64
#
# Top features for PC16:
# VEGETAZIONE_CATEGORIA_Querco-carpineti                                                                             0.467049
# VEGETAZIONE_CATEGORIA_Alneti planiziali e montani                                                                  0.369216
# VEGETAZIONE_TIPO_Faggeta eutrofica appenninica                                                                     0.340368
# VEGETAZIONE_CATEGORIA_Cerrete                                                                                      0.241084
# VEGETAZIONE_TIPO_Impianti di conifere                                                                              0.223615
# ...
# VEGETAZIONE_TIPO_Acero-tiglio-frassineto d'invasione                                0.213661
# VEGETAZIONE_TIPO_Castagneto da frutto                                               0.204987
# VEGETAZIONE_TIPO_Saliceto arbustivo ripario                                         0.189940
# VEGETAZIONE_TIPO_Arbusteto appenninico ad Erica arborea\n                           0.177728
# VEGETAZIONE_TIPO_Rimboschimento del piano montano                                   0.175488
# VEGETAZIONE_TIPO_Castagneto acidofilo a Teucrium scorodonia delle Alpi              0.171385
# VEGETAZIONE_TIPO_Alneto di ontano verde                                             0.171066
# VEGETAZIONE_TIPO_Faggeta appenninica a Physospermum cornubiense                     0.163197
# VEGETAZIONE_CATEGORIA_Alneti planiziali e montani                                   0.162821
# VEGETAZIONE_TIPO_Pioppeto di pioppo bianco                                          0.156356
# VEGETAZIONE_TIPO_Boscaglia rupestre pioniera                                        0.141549
# VEGETAZIONE_TIPO_Orno-ostrieto delle Alpi Liguri e Marittime                        0.135894
# VEGETAZIONE_TIPO_Querceto di rovere/roverella con orniello ed Erica cinerea         0.130071
# VEGETAZIONE_TIPO_Querco-carpineto della bassa pianura                               0.124615
# VEGETAZIONE_TIPO_Lariceto montano                                                   0.122767
# VEGETAZIONE_TIPO_Corileto d'invasione                                               0.111882
# VEGETAZIONE_TIPO_Querco-tiglieto                                                    0.107926
# VEGETAZIONE_TIPO_Impianti di conifere                                               0.107547
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris       0.101734
# VEGETAZIONE_TIPO_Querceto di rovere a Teucrium scorodonia                           0.091727
# VEGETAZIONE_TIPO_Robinieto                                                          0.091315
# VEGETAZIONE_TIPO_Pineta mesalpica basifila di pino silvestre                        0.087044
# VEGETAZIONE_TIPO_Betuleto planiziale di brughiera                                   0.086642
# VEGETAZIONE_TIPO_Castagneto mesoneutrofilo a Salvia glutinosa delle Alpi            0.085728
# analfabeti                                                                          0.084796
# VEGETAZIONE_TIPO_Querco-carpineto d'alta pianura ad elevate precipitazioni          0.083269
# Name: PC19, dtype: float64
#
# Top features for PC20:
# VEGETAZIONE_TIPO_Specie esotiche o naturalizzate                                        0.263294
# VEGETAZIONE_TIPO_Rimboschimento del piano subalpino                                     0.235412
# VEGETAZIONE_INTERVENTO_Aree per cui non si prevede intervento                           0.219468
# VEGETAZIONE_TIPO_Lariceto mesoxerofilo subalpino                                        0.213450
# VEGETAZIONE_TIPO_Specie spontanee                                                       0.211358
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                                          0.201734
# VEGETAZIONE_INTERVENTO_Evoluzione controllata (senza gestione attiva)                   0.197690
# VEGETAZIONE_TIPO_Pineta di pino uncinato eretto                                         0.183039
# VEGETAZIONE_TIPO_Pineta endalpica basifila di pino silvestre                            0.176303
# VEGETAZIONE_TIPO_Faggeta mesoxerofila                                                   0.166900
# VEGETAZIONE_TIPO_Faggeta mesotrofica                                                    0.166200
# VEGETAZIONE_TIPO_Faggeta oligotrofica                                                   0.161653
# VEGETAZIONE_TIPO_Pineta di brughiera su morene e terrazzi fluvio-glaciali               0.151174
# VEGETAZIONE_TIPO_Abetina altimontana a megaforbie                                       0.144475
# VEGETAZIONE_INTERVENTO_Ricostituzione boschiva, taglio fitosanitario o rinfoltimento    0.141912
# VEGETAZIONE_TIPO_Castagneto mesoneutrofilo a Salvia glutinosa delle Alpi                0.141387
# VEGETAZIONE_TIPO_?                                                                      0.138884
# VEGETAZIONE_TIPO_Lariceto a megaforbie                                                  0.136588
# VEGETAZIONE_INTERVENTO_Diradamento                                                      0.133988
# VEGETAZIONE_TIPO_Querceto xero-basifilo di roverella delle Alpi                         0.128205
# VEGETAZIONE_INTERVENTO_Evoluzione naturale                                              0.122541
# VEGETAZIONE_TIPO_Alneto di ontano nero                                                  0.117705
# VEGETAZIONE_TIPO_Pecceta montana mesalpica                                              0.116811
# VEGETAZIONE_TIPO_Acero-tiglio-frassineto d'invasione                                    0.111500
# VEGETAZIONE_TIPO_Querco-carpineto d'alta pianura ad elevate precipitazioni              0.103562
# VEGETAZIONE_TIPO_Lariceto dei campi di massi                                            0.103021
# VEGETAZIONE_TIPO_Betuleto montano                                                       0.101031
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale per collettivi                         0.100597
# VEGETAZIONE_TIPO_Pineta di pino montano prostrato                                       0.097750
# VEGETAZIONE_TIPO_Rimboschimento del piano montano                                       0.092336
# Name: PC20, dtype: float64
#
# Top features for PC22:
# VEGETAZIONE_TIPO_Specie spontanee                                                       0.300180
# VEGETAZIONE_TIPO_Pineta endalpica basifila di pino silvestre                            0.277599
# VEGETAZIONE_TIPO_Querceto mesoxerofilo di roverella delle Alpi                          0.272883
# VEGETAZIONE_INTERVENTO_Ceduazione                                                       0.240174
# VEGETAZIONE_TIPO_Faggeta eutrofica delle Alpi                                           0.233815
# VEGETAZIONE_INTERVENTO_Evoluzione controllata (senza gestione attiva)                   0.212589
# VEGETAZIONE_INTERVENTO_Ricostituzione boschiva, taglio fitosanitario o rinfoltimento    0.203884
# VEGETAZIONE_TIPO_Pineta di brughiera su morene e terrazzi fluvio-glaciali               0.197618
# VEGETAZIONE_INTERVENTO_Formazione lineare                                               0.190935
# VEGETAZIONE_TIPO_Cembreta xero-acidofila                                                0.174884
# VEGETAZIONE_TIPO_Querceto di rovere a Potentilla alba                                   0.155644
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale                                        0.148305
# VEGETAZIONE_INTERVENTO_Diradamento e conversione                                        0.142755
# VEGETAZIONE_TIPO_Specie esotiche o naturalizzate                                        0.140893
# VEGETAZIONE_TIPO_Querco-tiglieto                                                        0.132651
# VEGETAZIONE_TIPO_Lariceto a megaforbie                                                  0.130054
# VEGETAZIONE_INTERVENTO_Tagli successivi adattati                                        0.129946
# VEGETAZIONE_TIPO_Abetina endalpica                                                      0.125067
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                                          0.116728
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris           0.112595
# VEGETAZIONE_INTERVENTO_Gestione a ceduo composto                                        0.110568
# VEGETAZIONE_TIPO_Cerreta mista appenninica a Sesleria cylindrica                        0.109212
# VEGETAZIONE_TIPO_Abetina oligotrofica mesalpica                                         0.106228
# VEGETAZIONE_TIPO_Pineta endalpica di greto di pino silvestre                            0.101362
# VEGETAZIONE_TIPO_Pineta mesalpica basifila di pino silvestre                            0.100836
# VEGETAZIONE_TIPO_Abetina altimontana a megaforbie                                       0.097563
# VEGETAZIONE_INTERVENTO_Cure colturali                                                   0.096275
# VEGETAZIONE_TIPO_Rimboschimento del piano subalpino                                     0.096201
# VEGETAZIONE_TIPO_Faggeta mesotrofica                                                    0.093158
# analfabeti                                                                              0.087833
# Name: PC22, dtype: float64
#
# Top features for PC18:
# VEGETAZIONE_CATEGORIA_Filare doppio                                                                                0.584086
# VEGETAZIONE_CATEGORIA_Alneti planiziali e montani                                                                  0.326957
# VEGETAZIONE_TIPO_Impianti di conifere                                                                              0.325821
# VEGETAZIONE_CATEGORIA_Pinete di pino montano                                                                       0.272620
# VEGETAZIONE_TIPO_Robinieto                                                                                         0.178314
# VEGETAZIONE_TIPO_Castagneto neutrofilo dell'Appennino e dei rilievi collinari interni                              0.166688
# VEGETAZIONE_TIPO_Boscaglie d'invasione                                                                             0.162904
# VEGETAZIONE_TIPO_Pioppeti                                                                                          0.161811
# VEGETAZIONE_TIPO_Rimboschimento del piano montano                                                                  0.160752
# VEGETAZIONE_TIPO_Corileto d'invasione                                                                              0.147326
# VEGETAZIONE_TIPO_Impianti indifferenziati                                                                          0.142641
# VEGETAZIONE_TIPO_Querceto mesoxerofilo di roverella dei rilievi collinari interni e dell'Appennino                 0.139861
# VEGETAZIONE_TIPO_Castagneto acidofilo a Physospermum cornubiense dell'Appennino e dei rilievi collinari interni    0.139221
# VEGETAZIONE_TIPO_Orno-ostrieto dell'Appennino calcareo-marnoso a Knautia drymeia                                   0.116088
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella con Erica arborea                                            0.110106
# VEGETAZIONE_CATEGORIA_Arbusteti subalpini                                                                          0.107122
# VEGETAZIONE_CATEGORIA_Filare singolo                                                                               0.102392
# VEGETAZIONE_CATEGORIA_Abetine                                                                                      0.099199
# VEGETAZIONE_TIPO_Pineta di pino marittimo                                                                          0.097274
# analfabeti                                                                                                         0.083694
# VEGETAZIONE_TIPO_Faggeta eutrofica appenninica                                                                     0.079996
# VEGETAZIONE_CATEGORIA_Querco-carpineti                                                                             0.077186
# VEGETAZIONE_TIPO_Cerreta mesoxerofila                                                                              0.056073
# VEGETAZIONE_TIPO_Rimboschimento dei piani planiziale e collinare                                                   0.055562
# 9_24_diploma di tecnico superiore ITS o titolo di studio terziario di primo livello                                0.053235
# VEGETAZIONE_TIPO_Orno-querceto di roverella                                                                        0.051122
# VEGETAZIONE_TIPO_Arbusteto mesoxerofilo di Prunus spinosa e Cornus sanguinea                                       0.050112
# VEGETAZIONE_CATEGORIA_Arbusteti planiziali collinari e montani                                                     0.050059
# VEGETAZIONE_TIPO_Saliceto arbustivo ripario                                                                        0.045948
# VEGETAZIONE_CATEGORIA_Robinieti                                                                                    0.043357
# Name: PC18, dtype: float64
#
# Top features for PC10:
# VEGETAZIONE_INTERVENTO_Pascolamento di erbivori domestici o sfalcio delle praterie intercluse in ambiti forestali    0.623604
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale                                                                     0.412306
# VEGETAZIONE_INTERVENTO_Trasformazione                                                                                0.240422
# VEGETAZIONE_TIPO_Faggeta oligotrofica                                                                                0.166517
# VEGETAZIONE_DESTINAZ_Categorie di uso del suolo per cui non e' prevista una destinazione                             0.162005
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris                                        0.157772
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                                                                       0.144650
# VEGETAZIONE_INTERVENTO_Ricostituzione boschiva, taglio fitosanitario o rinfoltimento                                 0.138035
# VEGETAZIONE_TIPO_Pecceta montana endalpica                                                                           0.123972
# VEGETAZIONE_INTERVENTO_Evoluzione controllata                                                                        0.116620
# VEGETAZIONE_DESTINAZ_Mantenimento delle praterie di altitudine                                                       0.111191
# VEGETAZIONE_DESTINAZ_Produttiva                                                                                      0.108901
# VEGETAZIONE_TIPO_Specie esotiche o naturalizzate                                                                     0.107283
# VEGETAZIONE_TIPO_Querceto mesoxerofilo di roverella delle Alpi                                                       0.106878
# VEGETAZIONE_PRIORITA_Differibile - tra 11 e 15 anni                                                                  0.103882
# VEGETAZIONE_PRIORITA_Nessuna                                                                                         0.102660
# VEGETAZIONE_TIPO_Abetina oligotrofica mesalpica                                                                      0.100483
# VEGETAZIONE_PRIORITA_Breve termine - entro 5 anni                                                                    0.099499
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                                                     0.097619
# analfabeti                                                                                                           0.087545
# VEGETAZIONE_INTERVENTO_Evoluzione libera                                                                             0.084339
# VEGETAZIONE_TIPO_Pineta di pino uncinato eretto                                                                      0.080827
# VEGETAZIONE_ASSETTO_Ceduo in conversione                                                                             0.077674
# VEGETAZIONE_ASSETTO_Bosco di neoformazione (invasione)                                                               0.075076
# VEGETAZIONE_DESTINAZ_Naturalistica                                                                                   0.071932
# VEGETAZIONE_INTERVENTO_Evoluzione controllata (senza gestione attiva)                                                0.070907
# VEGETAZIONE_TIPO_Rimboschimento del piano subalpino                                                                  0.064888
# VEGETAZIONE_TIPO_Robinia pseudoacacia                                                                                0.064796
# VEGETAZIONE_INTERVENTO_Ceduazione                                                                                    0.063071
# VEGETAZIONE_INTERVENTO_Cure colturali                                                                                0.062527
# Name: PC10, dtype: float64

# %% [markdown]
# ---
