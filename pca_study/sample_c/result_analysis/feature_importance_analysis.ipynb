# %%
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
with open('/nfs/home/genovese/thesis-wildfire-genovese/pca_study/database/sample_c/trained_models/final_regression.pkl', 'rb') as f:
    r_model = pickle.load(f)

with open('/nfs/home/genovese/thesis-wildfire-genovese/pca_study/database/sample_c/trained_models/final_classification.pkl', 'rb') as f:
    c_model = pickle.load(f)

with open ('/nfs/home/genovese/thesis-wildfire-genovese/pca_study/database/sample_c/trained_models/pca.pkl', 'rb') as f:
    pca = pickle.load(f)
    
X_train = pd.read_csv('/nfs/home/genovese/thesis-wildfire-genovese/pca_study/database/sample_c/final_X_train_val.csv')
old_features = pd.read_csv('/nfs/home/genovese/thesis-wildfire-genovese/pca_study/database/sample_c/X_train_val.csv').columns

# %%
rf = pd.Series(r_model.feature_importances_, index=X_train.columns).sort_values(ascending=False)
cf = pd.Series(c_model.feature_importances_, index=X_train.columns).sort_values(ascending=False)

# %%
pd.concat([pd.Series(rf.index, name='regression'), pd.Series(cf.index, name='classification')], axis=1).to_latex()
# Out:
# "\\begin{tabular}{lll}\n\\toprule\n & regression & classification \\\\\n\\midrule\n0 & VEGETAZIONE_CATEGORIA_Castagneti & TOTALE_VEGETAZIONE \\\\\n1 & TOTALE_VEGETAZIONE & VEGETAZIONE_ASSETTO_Ceduo semplice con o senza matricine \\\\\n2 & TER_02 & VEGETAZIONE_PRIORITA_Nessuna \\\\\n3 & VEGETAZIONE_TIPO_Pioppeti & VEGETAZIONE_ASSETTO_Fustaia \\\\\n4 & Superficie a boschi & Reddito complessivo da 15000 a 26000 euro - Ammontare in euro \\\\\n5 & Reddito complessivo da 15000 a 26000 euro - Ammontare in euro & Reddito di spettanza dellimprenditore in contabilita semplificata - Ammontare in euro \\\\\n6 & TER_03 & Reddito complessivo da 55000 a 75000 euro - Ammontare in euro \\\\\n7 & terreni a riposo & VEGETAZIONE_ASSETTO_Ceduo composto (Fustaia sopra ceduo / ceduo sotto fustaia) \\\\\n8 & Superficie agricola utilizzata - ettari & 50_64_in altra condizione \\\\\n9 & piante industriali & VEGETAZIONE_CATEGORIA_Castagneti \\\\\n10 & cereali per la produzione di granella & AMB_02 \\\\\n11 & AMB_03 & SOC_01 \\\\\n12 & AMB_02 & SOC_02 \\\\\n13 & VEGETAZIONE_TIPO_Robinieto & TER_02 \\\\\n14 & totale ovini & SOC_04 \\\\\n15 & VEGETAZIONE_TIPO_Querceto di rovere a Potentilla alba & AMB_01 \\\\\n16 & Altra superficie rispetto a quella agricola utilizzata, a legna, a boschi e non utilizzata & SOC_03 \\\\\n17 & VEGETAZIONE_ASSETTO_Ceduo composto (Fustaia sopra ceduo / ceduo sotto fustaia) & TER_03 \\\\\n18 & SOC_01 & Superficie a boschi \\\\\n19 & Superficie per coltivazioni arboricole da legna & VEGETAZIONE_TIPO_Robinieto \\\\\n20 & patata & Superficie agricola utilizzata - ettari \\\\\n21 & Reddito complessivo da 55000 a 75000 euro - Ammontare in euro & cereali per la produzione di granella \\\\\n22 & SOC_02 & Superficie totale - ettari \\\\\n23 & AMB_01 & ECO_01 \\\\\n24 & Reddito di spettanza dellimprenditore in contabilita semplificata - Ammontare in euro & terreni a riposo \\\\\n25 & VEGETAZIONE_ASSETTO_Fustaia & totale ovini \\\\\n26 & SOC_04 & foraggere avvicendate \\\\\n27 & SOC_03 & totale alveari \\\\\n28 & VEGETAZIONE_PRIORITA_Nessuna & AMB_03 \\\\\n29 & VEGETAZIONE_ASSETTO_Ceduo semplice con o senza matricine & patata \\\\\n30 & ECO_01 & Altra superficie rispetto a quella agricola utilizzata, a legna, a boschi e non utilizzata \\\\\n31 & totale alveari & coltivazioni legnose agrarie \\\\\n32 & coltivazioni fruttifere & coltivazioni fruttifere \\\\\n33 & Superficie totale - ettari & piante industriali \\\\\n34 & vite & VEGETAZIONE_TIPO_Pioppeti \\\\\n35 & 50_64_in altra condizione & vite \\\\\n36 & foraggere avvicendate & Superficie per coltivazioni arboricole da legna \\\\\n37 & coltivazioni legnose agrarie & ortive protette in serra e tunnel accessibili all'uomo \\\\\n38 & ortive protette in serra e tunnel accessibili all'uomo & VEGETAZIONE_TIPO_Querceto di rovere a Potentilla alba \\\\\n\\bottomrule\n\\end{tabular}\n"

# %%
print(rf, '\n \n')
print(cf)
# Out:
# PC2     0.145415
# PC7     0.090991
# PC11    0.067232
# PC6     0.058212
# PC14    0.057558
# PC13    0.046511
# PC3     0.046312
# PC12    0.045273
# PC16    0.043760
# PC1     0.041989
# PC9     0.037957
# PC20    0.037942
# PC8     0.037628
# PC19    0.036834
# PC18    0.036412
# PC4     0.035921
# PC15    0.034165
# PC5     0.034131
# PC17    0.033271
# PC10    0.032484
# dtype: float64
#
#
# PC2     0.055389
# PC14    0.053864
# PC7     0.053681
# PC6     0.052669
# PC1     0.051878
# PC11    0.051161
# PC9     0.050910
# PC12    0.050191
# PC3     0.050169
# PC16    0.050116
# PC13    0.050095
# PC19    0.048680
# PC8     0.048410
# PC15    0.048394
# PC4     0.047818
# PC5     0.047666
# PC17    0.047558
# PC20    0.047524
# PC10    0.047152
# PC18    0.046674
# dtype: float64

# %%
pca_transform = pd.DataFrame(pca.components_, columns = [f'PC{n}' for n in range(1, len(old_features)+1)], index=old_features)
r_loadings = pca_transform.loc[:, [pc for pc in rf.index if 'PC' in pc]]
c_loadings = pca_transform.loc[:, [pc for pc in cf.index if 'PC' in pc]]

# %%
for col in pd.Series(list(r_loadings.columns)+list(c_loadings.columns)).unique():
    print(f"\nTop features for {col}:")
    top_features = r_loadings.loc[:, col].abs().sort_values(ascending=False).head(30)
    print(top_features)

for col in r_loadings.columns:
    print(f"\nTop features for {col}:")
    top_features = r_loadings.loc[:, col].abs().sort_values(ascending=False).head(30)
    print(top_features)
# Out:
# Top features for PC2:
# VEGETAZIONE_INTERVENTO_Evoluzione naturale                                                                                   0.427045
# VEGETAZIONE_INTERVENTO_Tagli successivi adattati                                                                             0.329598
# VEGETAZIONE_DESTINAZ_Evoluzione libera senza specifica destinazione(aree con valenza pastorale e prati stabili di pianura    0.306979
# VEGETAZIONE_INTERVENTO_Cure colturali                                                                                        0.264660
# VEGETAZIONE_PRIORITA_Medio termine - tra 6 e 10 anni                                                                         0.263130
# VEGETAZIONE_PRIORITA_Nessun intervento                                                                                       0.205374
# VEGETAZIONE_TIPO_Pineta endalpica di greto di pino silvestre                                                                 0.190659
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale                                                                             0.188761
# VEGETAZIONE_INTERVENTO_Evoluzione controllata (senza gestione attiva)                                                        0.147178
# VEGETAZIONE_TIPO_Lariceto a megaforbie                                                                                       0.134924
# VEGETAZIONE_INTERVENTO_Evoluzione controllata                                                                                0.129841
# VEGETAZIONE_INTERVENTO_Conversione attiva                                                                                    0.129312
# VEGETAZIONE_PRIORITA_Breve termine - entro 5 anni                                                                            0.127770
# VEGETAZIONE_INTERVENTO_Ceduazione                                                                                            0.127287
# VEGETAZIONE_TIPO_Specie esotiche o naturalizzate                                                                             0.123035
# VEGETAZIONE_ASSETTO_Ceduo in conversione                                                                                     0.123001
# VEGETAZIONE_PRIORITA_Aree per cui non si prevede priorita' d'intervento                                                      0.118008
# VEGETAZIONE_TIPO_Rimboschimento del piano subalpino                                                                          0.114044
# VEGETAZIONE_INTERVENTO_Evoluzione libera                                                                                     0.103610
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale per collettivi                                                              0.098747
# GP_RTP_4                                                                                                                     0.097226
# VEGETAZIONE_ASSETTO_Rimboschimento / fustaia artificiale                                                                     0.092795
# VEGETAZIONE_TIPO_Faggeta oligotrofica                                                                                        0.091089
# GP_RTP_3                                                                                                                     0.087219
# analfabeti                                                                                                                   0.086988
# VEGETAZIONE_TIPO_Pecceta subalpina                                                                                           0.081247
# VEGETAZIONE_DESTINAZ_Evoluzione libera senza specifica destinazione (superfici forestali)                                    0.079866
# VEGETAZIONE_TIPO_Querceto xero-basifilo di roverella delle Alpi                                                              0.078029
# VEGETAZIONE_TIPO_?                                                                                                           0.076766
# VEGETAZIONE_TIPO_Faggeta altimontana a megaforbie                                                                            0.075997
# Name: PC2, dtype: float64
#
# Top features for PC7:
# studente/ssa                                                             0.312809
# occupato                                                                 0.218280
# season                                                                   0.217639
# YYYY                                                                     0.212867
# VEGETAZIONE_DESTINAZ_Fruizione                                           0.187589
# Umidita' media ( % )_season                                              0.173344
# VEGETAZIONE_TIPO_Abetina endalpica                                       0.172307
# VEGETAZIONE_TIPO_Pineta endalpica acidofila di pino silvestre            0.168695
# VEGETAZIONE_INTERVENTO_Evoluzione controllata (senza gestione attiva)    0.159877
# VEGETAZIONE_INTERVENTO_Evoluzione naturale                               0.159068
# VEGETAZIONE_PRIORITA_Medio termine - tra 6 e 10 anni                     0.153345
# VEGETAZIONE_ASSETTO_Rimboschimento / fustaia artificiale                 0.141314
# VEGETAZIONE_INTERVENTO_Ceduazione                                        0.134134
# Settore Prevalente_season                                                0.133350
# VEGETAZIONE_DESTINAZ_Produttiva                                          0.130908
# Precipitazione dalle 0 alle 0 (mm)_season                                0.129539
# VEGETAZIONE_ASSETTO_Ceduo a sterzo (ceduo disetaneo)                     0.128582
# Tempo di permanenza nel settore ( min )_season                           0.126707
# 15_24_occupato                                                           0.124461
# VEGETAZIONE_TIPO_?                                                       0.123914
# Radiazione totale ( MJ/mq )_season                                       0.121479
# VEGETAZIONE_TIPO_Pecceta montana endalpica                               0.120931
# VEGETAZIONE_ASSETTO_Bosco di neoformazione (invasione)                   0.119735
# VEGETAZIONE_ASSETTO_Governo misto                                        0.119146
# Velocita' media del vento ( m/s )_season                                 0.117112
# Umidita' minima ( % )_season                                             0.116774
# VEGETAZIONE_DESTINAZ_Filare                                              0.115852
# VEGETAZIONE_TIPO_Faggeta altimontana a megaforbie                        0.113364
# VEGETAZIONE_TIPO_Betuleto planiziale di brughiera                        0.109683
# Direzione massima raffica ( ° )_season                                   0.106115
# Name: PC7, dtype: float64
#
# Top features for PC11:
# GP_RTP_3                                                                                                                     0.403212
# Calma di vento (min)_season                                                                                                  0.356657
# VEGETAZIONE_ASSETTO_Fustaia                                                                                                  0.299837
# VEGETAZIONE_ASSETTO_Ceduo in conversione                                                                                     0.277150
# VEGETAZIONE_ASSETTO_Rimboschimento / fustaia artificiale                                                                     0.234558
# Umidita' massima ( % )_season                                                                                                0.214056
# GP_RTP_4                                                                                                                     0.189211
# VEGETAZIONE_TIPO_Pineta endalpica basifila di pino silvestre                                                                 0.130971
# VEGETAZIONE_DESTINAZ_Evoluzione libera senza specifica destinazione(aree con valenza pastorale e prati stabili di pianura    0.130341
# VEGETAZIONE_ASSETTO_Ceduo composto (Fustaia sopra ceduo / ceduo sotto fustaia)                                               0.129841
# VEGETAZIONE_PRIORITA_Differibile - tra 11 e 15 anni                                                                          0.124555
# VEGETAZIONE_INTERVENTO_Evoluzione controllata                                                                                0.118968
# VEGETAZIONE_TIPO_Faggeta basifila pioniera                                                                                   0.106954
# VEGETAZIONE_DESTINAZ_Protettiva                                                                                              0.106281
# VEGETAZIONE_ASSETTO_Ceduo semplice con o senza matricine                                                                     0.105059
# Radiazione totale ( MJ/mq )_season                                                                                           0.103352
# VEGETAZIONE_DESTINAZ_Filare                                                                                                  0.100583
# VEGETAZIONE_INTERVENTO_Evoluzione naturale                                                                                   0.097800
# VEGETAZIONE_TIPO_Lariceto di greto                                                                                           0.096225
# VEGETAZIONE_INTERVENTO_Evoluzione libera                                                                                     0.095605
# VEGETAZIONE_TIPO_Acero-tiglio-frassineto di forra                                                                            0.094127
# VEGETAZIONE_TIPO_Querco-tiglieto                                                                                             0.092421
# VEGETAZIONE_PRIORITA_Medio termine - tra 6 e 10 anni                                                                         0.090550
# Temperatura massima ( °C )_season                                                                                            0.090413
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale                                                                             0.089575
# VEGETAZIONE_INTERVENTO_Mantenimento delle attuali pratiche colturali                                                         0.087096
# analfabeti                                                                                                                   0.087089
# VEGETAZIONE_ASSETTO_Categorie di uso del suolo per cui non e' descritto un assetto evolutivo                                 0.086025
# VEGETAZIONE_TIPO_Pineta endalpica mesoxerofila di pino silvestre                                                             0.082109
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                                                                               0.081649
# Name: PC11, dtype: float64
#
# Top features for PC6:
# VEGETAZIONE_INTERVENTO_Pascolamento di erbivori domestici o sfalcio delle praterie intercluse in ambiti forestali            0.362412
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale                                                                             0.290130
# VEGETAZIONE_INTERVENTO_Ricostituzione boschiva, taglio fitosanitario o rinfoltimento                                         0.243354
# VEGETAZIONE_INTERVENTO_Taglio a buche, a strisce, a fessura                                                                  0.221255
# VEGETAZIONE_DESTINAZ_Produttiva e protettiva                                                                                 0.218458
# VEGETAZIONE_ASSETTO_Fustaia                                                                                                  0.209366
# VEGETAZIONE_PRIORITA_Medio termine - tra 6 e 10 anni                                                                         0.194267
# VEGETAZIONE_ASSETTO_Categorie di uso del suolo per cui non e' descritto un assetto evolutivo                                 0.188314
# VEGETAZIONE_TIPO_Pineta endalpica acidofila di pino silvestre                                                                0.183454
# VEGETAZIONE_TIPO_Querceto xero-basifilo di roverella delle Alpi                                                              0.174720
# VEGETAZIONE_DESTINAZ_Produttiva                                                                                              0.167355
# VEGETAZIONE_INTERVENTO_Tagli successivi adattati                                                                             0.165803
# VEGETAZIONE_DESTINAZ_Fruizione                                                                                               0.152604
# VEGETAZIONE_INTERVENTO_Evoluzione libera                                                                                     0.151490
# VEGETAZIONE_INTERVENTO_Diradamento                                                                                           0.147054
# VEGETAZIONE_DESTINAZ_Filare con arbusti o siepe arbustiva                                                                    0.146173
# VEGETAZIONE_DESTINAZ_Naturalistica                                                                                           0.144063
# VEGETAZIONE_DESTINAZ_Evoluzione libera senza specifica destinazione(aree con valenza pastorale e prati stabili di pianura    0.134333
# VEGETAZIONE_INTERVENTO_Conversione attiva                                                                                    0.131426
# VEGETAZIONE_PRIORITA_Breve termine - entro 5 anni                                                                            0.127840
# VEGETAZIONE_PRIORITA_Nessuna                                                                                                 0.111226
# VEGETAZIONE_INTERVENTO_Ceduazione                                                                                            0.109223
# VEGETAZIONE_ASSETTO_Bosco di neoformazione (invasione)                                                                       0.107779
# VEGETAZIONE_ASSETTO_Ceduo semplice con o senza matricine                                                                     0.107388
# VEGETAZIONE_DESTINAZ_Siepe arbustiva                                                                                         0.103341
# VEGETAZIONE_TIPO_Pineta mesalpica acidofila di pino silvestre                                                                0.095227
# analfabeti                                                                                                                   0.086889
# VEGETAZIONE_PRIORITA_Differibile - tra 11 e 15 anni                                                                          0.085491
# VEGETAZIONE_PRIORITA_Nessun intervento                                                                                       0.084251
# VEGETAZIONE_TIPO_Lariceto a megaforbie                                                                                       0.083796
# Name: PC6, dtype: float64
#
# Top features for PC14:
# GP_RTP_4                                                                                        0.392969
# VEGETAZIONE_ASSETTO_Ceduo composto (Fustaia sopra ceduo / ceduo sotto fustaia)                  0.320147
# VEGETAZIONE_ASSETTO_Ceduo semplice con o senza matricine                                        0.297390
# VEGETAZIONE_DESTINAZ_Filare                                                                     0.219628
# VEGETAZIONE_ASSETTO_Ceduo a sterzo (ceduo disetaneo)                                            0.210248
# VEGETAZIONE_ASSETTO_Bosco senza gestione per condizionamenti stazionali                         0.204803
# VEGETAZIONE_ASSETTO_Governo misto                                                               0.186264
# VEGETAZIONE_INTERVENTO_Trasformazione                                                           0.174976
# VEGETAZIONE_ASSETTO_Fustaia                                                                     0.174672
# Precipitazione dalle 0 alle 0 (mm)_season                                                       0.147014
# Umidita' massima ( % )_season                                                                   0.136507
# VEGETAZIONE_ASSETTO_Bosco di neoformazione (invasione)                                          0.127128
# VEGETAZIONE_ASSETTO_Ceduo in conversione                                                        0.124950
# VEGETAZIONE_ASSETTO_Rimboschimento / fustaia artificiale                                        0.123693
# Temperatura media dei massimi ( °C )_season                                                     0.112103
# season                                                                                          0.109241
# Calma di vento (min)_season                                                                     0.109118
# VEGETAZIONE_ASSETTO_Categorie di uso del suolo per cui non e' descritto un assetto evolutivo    0.108699
# Umidita' media ( % )_season                                                                     0.106894
# GP_RTP_2                                                                                        0.102645
# VEGETAZIONE_TIPO_Pineta endalpica basifila di pino silvestre                                    0.100534
# VEGETAZIONE_TIPO_Faggeta oligotrofica                                                           0.097439
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale per collettivi                                 0.096865
# VEGETAZIONE_TIPO_Pineta endalpica mesoxerofila di pino silvestre                                0.096195
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale                                                0.094963
# VEGETAZIONE_TIPO_Cembreta xero-acidofila                                                        0.094218
# VEGETAZIONE_DESTINAZ_Siepe arbustiva                                                            0.093093
# VEGETAZIONE_DESTINAZ_Protettiva                                                                 0.091725
# VEGETAZIONE_TIPO_Abetina endalpica                                                              0.091133
# analfabeti                                                                                      0.086995
# Name: PC14, dtype: float64
#
# Top features for PC13:
# VEGETAZIONE_ASSETTO_Rimboschimento / fustaia artificiale                                                                     0.462955
# GP_RTP_1                                                                                                                     0.249320
# Precipitazione dalle 0 alle 0 (mm)_season                                                                                    0.244957
# VEGETAZIONE_ASSETTO_Categorie di uso del suolo per cui non e' descritto un assetto evolutivo                                 0.243961
# VEGETAZIONE_ASSETTO_Bosco senza gestione per condizionamenti stazionali                                                      0.238587
# VEGETAZIONE_ASSETTO_Ceduo a sterzo (ceduo disetaneo)                                                                         0.219628
# GP_RTP_3                                                                                                                     0.176403
# GP_RTP_5                                                                                                                     0.169736
# VEGETAZIONE_DESTINAZ_Protettiva                                                                                              0.146161
# VEGETAZIONE_INTERVENTO_Evoluzione naturale                                                                                   0.143396
# VEGETAZIONE_ASSETTO_Fustaia                                                                                                  0.141993
# VEGETAZIONE_ASSETTO_Bosco di neoformazione (invasione)                                                                       0.141651
# VEGETAZIONE_PRIORITA_Nessun intervento                                                                                       0.138621
# GP_RTP_4                                                                                                                     0.128521
# occupato                                                                                                                     0.126223
# Settore Prevalente_season                                                                                                    0.118195
# VEGETAZIONE_TIPO_Pineta endalpica di greto di pino silvestre                                                                 0.114160
# VEGETAZIONE_DESTINAZ_Evoluzione libera senza specifica destinazione(aree con valenza pastorale e prati stabili di pianura    0.113182
# Direzione massima raffica ( ° )_season                                                                                       0.097685
# VEGETAZIONE_ASSETTO_Ceduo in conversione                                                                                     0.097656
# VEGETAZIONE_DESTINAZ_Produttiva e protettiva                                                                                 0.097468
# VEGETAZIONE_TIPO_Cembreta xero-acidofila                                                                                     0.095818
# VEGETAZIONE_TIPO_Pineta endalpica acidofila di pino silvestre                                                                0.095261
# VEGETAZIONE_TIPO_Faggeta oligotrofica                                                                                        0.095217
# VEGETAZIONE_PRIORITA_Breve termine - entro 5 anni                                                                            0.094671
# VEGETAZIONE_TIPO_Pineta endalpica mesoxerofila di pino silvestre                                                             0.094638
# VEGETAZIONE_INTERVENTO_Ricostituzione boschiva, taglio fitosanitario o rinfoltimento                                         0.094509
# VEGETAZIONE_DESTINAZ_Filare                                                                                                  0.094265
# VEGETAZIONE_DESTINAZ_Mantenimento delle praterie di altitudine                                                               0.092763
# analfabeti                                                                                                                   0.087134
# Name: PC13, dtype: float64
#
# Top features for PC3:
# VEGETAZIONE_INTERVENTO_Diradamento e conversione                                            0.486004
# VEGETAZIONE_INTERVENTO_Evoluzione controllata                                               0.371567
# VEGETAZIONE_INTERVENTO_Aree per cui non si prevede intervento                               0.329878
# VEGETAZIONE_INTERVENTO_Tagli successivi adattati                                            0.222364
# VEGETAZIONE_INTERVENTO_Diradamento                                                          0.217444
# VEGETAZIONE_DESTINAZ_Produttiva e protettiva                                                0.181693
# VEGETAZIONE_TIPO_Pineta endalpica basifila di pino silvestre                                0.160566
# VEGETAZIONE_ASSETTO_Governo misto                                                           0.149576
# VEGETAZIONE_INTERVENTO_Evoluzione libera                                                    0.147774
# VEGETAZIONE_TIPO_Pineta endalpica di greto di pino silvestre                                0.133484
# VEGETAZIONE_TIPO_Querceto xero-basifilo di roverella delle Alpi                             0.120606
# VEGETAZIONE_TIPO_Faggeta oligotrofica                                                       0.116478
# VEGETAZIONE_INTERVENTO_Ceduazione                                                           0.106942
# VEGETAZIONE_TIPO_?                                                                          0.104925
# VEGETAZIONE_INTERVENTO_Trasformazione                                                       0.102515
# VEGETAZIONE_INTERVENTO_Taglio a buche, a strisce, a fessura                                 0.100572
# VEGETAZIONE_INTERVENTO_Evoluzione naturale                                                  0.097862
# Calma di vento (min)_season                                                                 0.097839
# VEGETAZIONE_DESTINAZ_Protettiva                                                             0.096983
# VEGETAZIONE_PRIORITA_Breve termine - entro 5 anni                                           0.093279
# VEGETAZIONE_TIPO_Lariceto montano                                                           0.091853
# VEGETAZIONE_TIPO_Querco-tiglieto                                                            0.091194
# VEGETAZIONE_DESTINAZ_Filare                                                                 0.090797
# VEGETAZIONE_DESTINAZ_Categorie di uso del suolo per cui non e' prevista una destinazione    0.087966
# analfabeti                                                                                  0.087027
# VEGETAZIONE_ASSETTO_Ceduo a sterzo (ceduo disetaneo)                                        0.084897
# VEGETAZIONE_TIPO_Pineta endalpica acidofila di pino silvestre                               0.082680
# VEGETAZIONE_INTERVENTO_Cure colturali                                                       0.079223
# Precipitazione dalle 0 alle 0 (mm)_season                                                   0.078606
# VEGETAZIONE_INTERVENTO_Evoluzione controllata (senza gestione attiva)                       0.075136
# Name: PC3, dtype: float64
#
# Top features for PC12:
# VEGETAZIONE_ASSETTO_Bosco di neoformazione (invasione)                                          0.388927
# VEGETAZIONE_ASSETTO_Governo misto                                                               0.307827
# VEGETAZIONE_ASSETTO_Ceduo semplice con o senza matricine                                        0.276660
# Direzione massima raffica ( ° )_season                                                          0.235344
# GP_RTP_2                                                                                        0.206901
# VEGETAZIONE_DESTINAZ_Filare con arbusti o siepe arbustiva                                       0.199747
# VEGETAZIONE_DESTINAZ_Naturalistica                                                              0.196352
# VEGETAZIONE_ASSETTO_Ceduo composto (Fustaia sopra ceduo / ceduo sotto fustaia)                  0.184972
# VEGETAZIONE_DESTINAZ_Produttiva e protettiva                                                    0.183893
# VEGETAZIONE_TIPO_?                                                                              0.167487
# VEGETAZIONE_ASSETTO_Categorie di uso del suolo per cui non e' descritto un assetto evolutivo    0.166284
# VEGETAZIONE_ASSETTO_Bosco senza gestione per condizionamenti stazionali                         0.162504
# VEGETAZIONE_DESTINAZ_Evoluzione libera senza specifica destinazione (superfici forestali)       0.138588
# VEGETAZIONE_DESTINAZ_Protettiva                                                                 0.136817
# VEGETAZIONE_DESTINAZ_Categorie di uso del suolo per cui non e' prevista una destinazione        0.132768
# Settore Prevalente_season                                                                       0.125242
# VEGETAZIONE_PRIORITA_Breve termine - entro 5 anni                                               0.122820
# VEGETAZIONE_TIPO_Faggeta basifila pioniera                                                      0.120332
# Giorni piovosi pioggia dalle 0 alle 0_season                                                    0.118803
# VEGETAZIONE_DESTINAZ_Filare                                                                     0.114792
# VEGETAZIONE_TIPO_Pineta endalpica mesoxerofila di pino silvestre                                0.103590
# VEGETAZIONE_ASSETTO_Rimboschimento / fustaia artificiale                                        0.097906
# Calma di vento (min)_season                                                                     0.092378
# VEGETAZIONE_PRIORITA_Nessun intervento                                                          0.092182
# VEGETAZIONE_TIPO_Lariceto di greto                                                              0.089547
# analfabeti                                                                                      0.087136
# VEGETAZIONE_TIPO_Pecceta subalpina                                                              0.086405
# VEGETAZIONE_DESTINAZ_Fruizione                                                                  0.086337
# VEGETAZIONE_TIPO_Acero-tiglio-frassineto di forra                                               0.084985
# VEGETAZIONE_TIPO_Faggeta oligotrofica                                                           0.082789
# Name: PC12, dtype: float64
#
# Top features for PC16:
# VEGETAZIONE_TIPO_Castagneto da frutto                                                                              0.370993
# VEGETAZIONE_TIPO_Larici-cembreto su rodoreto-vaccinieto                                                            0.344705
# VEGETAZIONE_TIPO_Pecceta montana mesalpica                                                                         0.328940
# VEGETAZIONE_TIPO_Acero-tiglio-frassineto di forra                                                                  0.238197
# VEGETAZIONE_TIPO_Acero-tiglio-frassineto d'invasione                                                               0.227522
# VEGETAZIONE_TIPO_Faggeta eutrofica delle Alpi                                                                      0.219710
# VEGETAZIONE_TIPO_Betuleto montano                                                                                  0.216507
# VEGETAZIONE_TIPO_Querceto di rovere a Teucrium scorodonia                                                          0.188504
# VEGETAZIONE_TIPO_Betuleto planiziale di brughiera                                                                  0.184957
# VEGETAZIONE_TIPO_Pioppeto d'invasione a pioppo tremolo                                                             0.180636
# VEGETAZIONE_TIPO_Castagneto mesoneutrofilo a Salvia glutinosa delle Alpi                                           0.178752
# VEGETAZIONE_TIPO_Orno-ostrieto delle Alpi Liguri e Marittime                                                       0.173870
# VEGETAZIONE_TIPO_Pineta mesalpica acidofila di pino silvestre                                                      0.161261
# VEGETAZIONE_TIPO_Abetina oligotrofica mesalpica                                                                    0.151218
# VEGETAZIONE_TIPO_Querco-carpineto d'alta pianura ad elevate precipitazioni                                         0.136021
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris                                      0.132090
# VEGETAZIONE_TIPO_Lariceto montano                                                                                  0.118196
# VEGETAZIONE_TIPO_Cerreta mesofila                                                                                  0.104550
# VEGETAZIONE_TIPO_Pineta endalpica mesoxerofila di pino silvestre                                                   0.102167
# VEGETAZIONE_TIPO_Pineta di pino montano prostrato                                                                  0.099283
# VEGETAZIONE_TIPO_Castagneto acidofilo a Physospermum cornubiense dell'Appennino e dei rilievi collinari interni    0.098939
# VEGETAZIONE_TIPO_Arbusteto rupestre di Amelanchier ovalis                                                          0.096033
# VEGETAZIONE_TIPO_Arbusteto montano di Buxus sempervirens                                                           0.090606
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                                                   0.086024
# analfabeti                                                                                                         0.084417
# VEGETAZIONE_TIPO_Alneto di ontano verde                                                                            0.081853
# VEGETAZIONE_TIPO_Faggeta mesoxerofila                                                                              0.080145
# VEGETAZIONE_TIPO_Castagneto acidofilo a Teucrium scorodonia delle Alpi                                             0.075142
# VEGETAZIONE_TIPO_Rimboschimento dei piani planiziale e collinare                                                   0.063728
# VEGETAZIONE_TIPO_Faggeta basifila pioniera                                                                         0.063451
# Name: PC16, dtype: float64
#
# Top features for PC1:
# VEGETAZIONE_TIPO_Arbusteto rupestre di Amelanchier ovalis                        0.431197
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                 0.368867
# VEGETAZIONE_TIPO_Faggeta altimontana a megaforbie                                0.340921
# VEGETAZIONE_TIPO_Pineta di pino montano prostrato                                0.319433
# VEGETAZIONE_TIPO_Lariceto montano                                                0.291013
# VEGETAZIONE_TIPO_Rimboschimento del piano subalpino                              0.228358
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                                   0.212391
# VEGETAZIONE_TIPO_Pineta endalpica mesoxerofila di pino silvestre                 0.161914
# VEGETAZIONE_TIPO_Pineta di pino uncinato eretto                                  0.157205
# VEGETAZIONE_TIPO_Querceto di rovere/roverella con orniello ed Erica cinerea      0.142123
# VEGETAZIONE_TIPO_Lariceto pascolivo                                              0.138444
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris    0.120909
# VEGETAZIONE_TIPO_Pineta mesalpica basifila di pino silvestre                     0.111586
# VEGETAZIONE_TIPO_Betuleto planiziale di brughiera                                0.105891
# VEGETAZIONE_TIPO_Pineta di brughiera su morene e terrazzi fluvio-glaciali        0.099314
# VEGETAZIONE_TIPO_Pecceta montana endalpica                                       0.099027
# VEGETAZIONE_TIPO_Pineta endalpica basifila di pino silvestre                     0.095334
# VEGETAZIONE_TIPO_Pecceta montana mesalpica                                       0.093690
# VEGETAZIONE_TIPO_Alneto di ontano bianco                                         0.090715
# analfabeti                                                                       0.086886
# VEGETAZIONE_TIPO_Abetina endalpica                                               0.084663
# VEGETAZIONE_TIPO_Faggeta oligotrofica                                            0.082336
# VEGETAZIONE_TIPO_Abetina eutrofica                                               0.078858
# VEGETAZIONE_TIPO_Lariceto a megaforbie                                           0.071609
# VEGETAZIONE_TIPO_Faggeta mesoxerofila                                            0.069875
# VEGETAZIONE_TIPO_Pineta endalpica di greto di pino silvestre                     0.069830
# VEGETAZIONE_TIPO_Specie spontanee                                                0.065107
# VEGETAZIONE_TIPO_Querceto xero-basifilo di roverella delle Alpi                  0.062481
# VEGETAZIONE_TIPO_Lariceto di greto                                               0.057010
# VEGETAZIONE_TIPO_Orno-ostrieto delle Alpi Liguri e Marittime                     0.052902
# Name: PC1, dtype: float64
#
# Top features for PC9:
# VEGETAZIONE_TIPO_Arbusteto rupestre di Amelanchier ovalis           0.336263
# VEGETAZIONE_TIPO_Querceto xero-basifilo di roverella delle Alpi     0.299398
# VEGETAZIONE_TIPO_Pineta di pino montano prostrato                   0.285162
# VEGETAZIONE_TIPO_Betuleto planiziale di brughiera                   0.258507
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                      0.253871
# VEGETAZIONE_TIPO_Faggeta eutrofica delle Alpi                       0.239071
# VEGETAZIONE_TIPO_Faggeta altimontana a megaforbie                   0.233801
# VEGETAZIONE_TIPO_Faggeta basifila pioniera                          0.211810
# VEGETAZIONE_TIPO_Abetina eutrofica                                  0.192060
# VEGETAZIONE_TIPO_Lariceto montano                                   0.174673
# VEGETAZIONE_TIPO_Lariceto di greto                                  0.172380
# VEGETAZIONE_TIPO_Abetina endalpica                                  0.170998
# VEGETAZIONE_TIPO_Faggeta oligotrofica                               0.166524
# VEGETAZIONE_TIPO_Lariceto a megaforbie                              0.158210
# VEGETAZIONE_TIPO_Abetina altimontana a megaforbie                   0.154874
# VEGETAZIONE_TIPO_Pecceta subalpina                                  0.151327
# VEGETAZIONE_TIPO_Specie spontanee                                   0.120433
# VEGETAZIONE_TIPO_Querceto mesoxerofilo di roverella delle Alpi      0.117075
# VEGETAZIONE_TIPO_Pineta di pino uncinato eretto                     0.114181
# VEGETAZIONE_TIPO_Cembreta xero-acidofila                            0.111796
# VEGETAZIONE_TIPO_Faggeta mesoxerofila                               0.097468
# VEGETAZIONE_TIPO_Pineta endalpica basifila di pino silvestre        0.093938
# VEGETAZIONE_TIPO_Pineta mesalpica acidofila di pino silvestre       0.093148
# VEGETAZIONE_TIPO_Pineta endalpica mesoxerofila di pino silvestre    0.088482
# analfabeti                                                          0.085429
# VEGETAZIONE_TIPO_Alneto di ontano verde\n                           0.084799
# VEGETAZIONE_INTERVENTO_Gestione a ceduo composto                    0.071903
# VEGETAZIONE_TIPO_Pineta mesalpica basifila di pino silvestre        0.070918
# VEGETAZIONE_TIPO_Querco-tiglieto                                    0.066183
# VEGETAZIONE_TIPO_Pecceta montana endalpica                          0.065270
# Name: PC9, dtype: float64
#
# Top features for PC20:
# GP_RTP_4                                                                                                                     0.286403
# VEGETAZIONE_ASSETTO_Categorie di uso del suolo per cui non e' descritto un assetto evolutivo                                 0.268045
# VEGETAZIONE_DESTINAZ_Produttiva e protettiva                                                                                 0.231341
# Precipitazione dalle 0 alle 0 (mm)_season                                                                                    0.226490
# Radiazione totale ( MJ/mq )_season                                                                                           0.213248
# VEGETAZIONE_DESTINAZ_Evoluzione libera senza specifica destinazione(aree con valenza pastorale e prati stabili di pianura    0.205619
# VEGETAZIONE_PRIORITA_Aree per cui non si prevede priorita' d'intervento                                                      0.198485
# VEGETAZIONE_INTERVENTO_Trasformazione                                                                                        0.188890
# VEGETAZIONE_ASSETTO_Rimboschimento / fustaia artificiale                                                                     0.176480
# GP_RTP_2                                                                                                                     0.158775
# VEGETAZIONE_ASSETTO_Ceduo semplice con o senza matricine                                                                     0.153202
# VEGETAZIONE_DESTINAZ_Filare                                                                                                  0.148294
# VEGETAZIONE_DESTINAZ_Categorie di uso del suolo per cui non e' prevista una destinazione                                     0.147093
# GP_RTP_3                                                                                                                     0.145335
# VEGETAZIONE_DESTINAZ_Protettiva                                                                                              0.144512
# VEGETAZIONE_TIPO_Pineta endalpica acidofila di pino silvestre                                                                0.137449
# VEGETAZIONE_TIPO_Acero-tiglio-frassineto di forra                                                                            0.123850
# VEGETAZIONE_DESTINAZ_Siepe arbustiva                                                                                         0.123309
# VEGETAZIONE_TIPO_Specie spontanee                                                                                            0.118024
# Tempo di permanenza nel settore ( min )_season                                                                               0.113219
# Direzione massima raffica ( ° )_season                                                                                       0.110654
# VEGETAZIONE_TIPO_Pineta endalpica mesoxerofila di pino silvestre                                                             0.109761
# VEGETAZIONE_PRIORITA_Medio termine - tra 6 e 10 anni                                                                         0.109167
# Temperatura media ( °C )_season                                                                                              0.104243
# VEGETAZIONE_TIPO_Larici-cembreto su rodoreto-vaccinieto                                                                      0.101374
# VEGETAZIONE_INTERVENTO_Cure colturali                                                                                        0.098573
# VEGETAZIONE_PRIORITA_Nessun intervento                                                                                       0.097035
# VEGETAZIONE_DESTINAZ_Filare con arbusti o siepe arbustiva                                                                    0.094488
# VEGETAZIONE_INTERVENTO_Diradamento                                                                                           0.094447
# VEGETAZIONE_TIPO_Querceto xero-basifilo di roverella delle Alpi                                                              0.089411
# Name: PC20, dtype: float64
#
# Top features for PC8:
# occupato                                                                                        0.291762
# studente/ssa                                                                                    0.277617
# VEGETAZIONE_ASSETTO_Categorie di uso del suolo per cui non e' descritto un assetto evolutivo    0.241570
# YYYY                                                                                            0.222689
# season                                                                                          0.215435
# VEGETAZIONE_INTERVENTO_Evoluzione controllata                                                   0.185853
# VEGETAZIONE_PRIORITA_Medio termine - tra 6 e 10 anni                                            0.174660
# VEGETAZIONE_TIPO_Abetina endalpica                                                              0.174419
# VEGETAZIONE_TIPO_Pineta endalpica acidofila di pino silvestre                                   0.153025
# VEGETAZIONE_DESTINAZ_Produttiva                                                                 0.148741
# VEGETAZIONE_INTERVENTO_Ceduazione                                                               0.144368
# VEGETAZIONE_INTERVENTO_Cure colturali                                                           0.140824
# VEGETAZIONE_DESTINAZ_Filare con arbusti o siepe arbustiva                                       0.132955
# VEGETAZIONE_PRIORITA_Nessun intervento                                                          0.129678
# VEGETAZIONE_ASSETTO_Rimboschimento / fustaia artificiale                                        0.123717
# Calma di vento (min)_season                                                                     0.122908
# VEGETAZIONE_TIPO_?                                                                              0.121653
# Velocita' media del vento ( m/s )_season                                                        0.119943
# VEGETAZIONE_INTERVENTO_Evoluzione controllata (senza gestione attiva)                           0.118910
# VEGETAZIONE_TIPO_Pecceta montana endalpica                                                      0.118018
# VEGETAZIONE_INTERVENTO_Taglio a buche, a strisce, a fessura                                     0.117343
# VEGETAZIONE_TIPO_Querceto xero-basifilo di roverella delle Alpi                                 0.116628
# 15_24_occupato                                                                                  0.114668
# VEGETAZIONE_DESTINAZ_Fruizione                                                                  0.112669
# GP_RTP_3                                                                                        0.112134
# VEGETAZIONE_TIPO_Faggeta altimontana a megaforbie                                               0.111197
# VEGETAZIONE_INTERVENTO_Tagli successivi adattati                                                0.108969
# VEGETAZIONE_TIPO_Betuleto planiziale di brughiera                                               0.107579
# Umidita' minima ( % )_season                                                                    0.096606
# VEGETAZIONE_TIPO_Lariceto montano                                                               0.095016
# Name: PC8, dtype: float64
#
# Top features for PC19:
# VEGETAZIONE_TIPO_Lariceto montano                                                0.330354
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris    0.311397
# VEGETAZIONE_TIPO_Pineta mesalpica acidofila di pino silvestre                    0.303865
# VEGETAZIONE_TIPO_Querceto xero-basifilo di roverella delle Alpi                  0.281581
# VEGETAZIONE_TIPO_Faggeta basifila pioniera                                       0.256326
# VEGETAZIONE_TIPO_Pecceta montana endalpica                                       0.226807
# VEGETAZIONE_TIPO_Specie esotiche o naturalizzate                                 0.199681
# VEGETAZIONE_TIPO_Arbusteto rupestre di Amelanchier ovalis                        0.190835
# VEGETAZIONE_TIPO_Faggeta altimontana a megaforbie                                0.176034
# VEGETAZIONE_TIPO_Pecceta montana mesalpica                                       0.167926
# VEGETAZIONE_TIPO_Pineta di pino uncinato eretto                                  0.158610
# VEGETAZIONE_TIPO_Rimboschimento del piano subalpino                              0.152449
# VEGETAZIONE_TIPO_Acero-tiglio-frassineto di forra                                0.146711
# VEGETAZIONE_TIPO_Larici-cembreto su rodoreto-vaccinieto                          0.142555
# VEGETAZIONE_TIPO_Pineta endalpica basifila di pino silvestre                     0.136019
# VEGETAZIONE_TIPO_Betuleto planiziale di brughiera                                0.129257
# VEGETAZIONE_TIPO_Lariceto di greto                                               0.120526
# VEGETAZIONE_TIPO_Faggeta oligotrofica                                            0.111226
# VEGETAZIONE_TIPO_Querco-tiglieto                                                 0.110318
# VEGETAZIONE_TIPO_Querceto di rovere/roverella con orniello ed Erica cinerea      0.100186
# VEGETAZIONE_TIPO_Alneto di ontano bianco                                         0.092735
# VEGETAZIONE_TIPO_Cembreta xero-acidofila                                         0.090723
# VEGETAZIONE_TIPO_Abetina oligotrofica mesalpica                                  0.087505
# VEGETAZIONE_TIPO_Pineta endalpica mesoxerofila di pino silvestre                 0.087412
# VEGETAZIONE_TIPO_Lariceto pascolivo                                              0.085952
# analfabeti                                                                       0.085713
# VEGETAZIONE_TIPO_Pecceta subalpina                                               0.085156
# VEGETAZIONE_TIPO_Pineta endalpica acidofila di pino silvestre                    0.083218
# VEGETAZIONE_TIPO_Castagneto da frutto                                            0.074722
# VEGETAZIONE_TIPO_Abetina altimontana a megaforbie                                0.074256
# Name: PC19, dtype: float64
#
# Top features for PC18:
# VEGETAZIONE_TIPO_Querco-tiglieto                                                 0.416664
# VEGETAZIONE_TIPO_Lariceto montano                                                0.382888
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                 0.377130
# VEGETAZIONE_TIPO_Lariceto pascolivo                                              0.358715
# VEGETAZIONE_TIPO_Pecceta montana mesalpica                                       0.310721
# VEGETAZIONE_TIPO_Betuleto planiziale di brughiera                                0.207105
# VEGETAZIONE_TIPO_Faggeta oligotrofica                                            0.152758
# VEGETAZIONE_TIPO_Betuleto montano                                                0.150964
# ...
# VEGETAZIONE_TIPO_Arbusteto rupestre di Amelanchier ovalis                        0.101290
# VEGETAZIONE_TIPO_Abetina oligotrofica mesalpica                                  0.088503
# analfabeti                                                                       0.085673
# VEGETAZIONE_TIPO_Acero-tiglio-frassineto di forra                                0.080755
# VEGETAZIONE_TIPO_Querco-carpineto d'alta pianura ad elevate precipitazioni       0.080687
# VEGETAZIONE_TIPO_Pecceta montana endalpica                                       0.071193
# VEGETAZIONE_TIPO_Lariceto dei campi di massi                                     0.058488
# VEGETAZIONE_TIPO_Faggeta mesoxerofila                                            0.058374
# VEGETAZIONE_TIPO_Castagneto acidofilo a Teucrium scorodonia delle Alpi           0.049056
# VEGETAZIONE_TIPO_Castagneto da frutto                                            0.039500
# VEGETAZIONE_TIPO_Cerreta mesofila                                                0.037622
# VEGETAZIONE_TIPO_Pineta di brughiera su morene e terrazzi fluvio-glaciali        0.037379
# VEGETAZIONE_TIPO_Acero-tiglio-frassineto d'invasione                             0.037323
# Name: PC18, dtype: float64
#
# Top features for PC4:
# VEGETAZIONE_DESTINAZ_Categorie di uso del suolo per cui non e' prevista una destinazione                             0.321938
# VEGETAZIONE_PRIORITA_Breve termine - entro 5 anni                                                                    0.261919
# VEGETAZIONE_DESTINAZ_Produttiva                                                                                      0.231075
# VEGETAZIONE_INTERVENTO_Trasformazione                                                                                0.206380
# VEGETAZIONE_INTERVENTO_Pascolamento di erbivori domestici o sfalcio delle praterie intercluse in ambiti forestali    0.198554
# Direzione massima raffica ( ° )_season                                                                               0.197771
# Calma di vento (min)_season                                                                                          0.187217
# GP_RTP_1                                                                                                             0.178644
# Temperatura media dei massimi ( °C )_season                                                                          0.174521
# VEGETAZIONE_PRIORITA_Aree per cui non si prevede priorita' d'intervento                                              0.172982
# VEGETAZIONE_INTERVENTO_Evoluzione controllata                                                                        0.171211
# VEGETAZIONE_DESTINAZ_Naturalistica                                                                                   0.168959
# VEGETAZIONE_DESTINAZ_Protettiva                                                                                      0.162086
# VEGETAZIONE_ASSETTO_Rimboschimento / fustaia artificiale                                                             0.159132
# VEGETAZIONE_DESTINAZ_Produttiva e protettiva                                                                         0.157922
# VEGETAZIONE_ASSETTO_Bosco senza gestione per condizionamenti stazionali                                              0.154553
# occupato                                                                                                             0.146937
# VEGETAZIONE_INTERVENTO_Tagli successivi adattati                                                                     0.140582
# VEGETAZIONE_PRIORITA_Medio termine - tra 6 e 10 anni                                                                 0.138005
# Settore Prevalente_season                                                                                            0.137458
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale per collettivi                                                      0.122804
# VEGETAZIONE_ASSETTO_Categorie di uso del suolo per cui non e' descritto un assetto evolutivo                         0.119715
# VEGETAZIONE_INTERVENTO_Cure colturali                                                                                0.118249
# VEGETAZIONE_INTERVENTO_Evoluzione controllata (senza gestione attiva)                                                0.117764
# GP_RTP_5                                                                                                             0.111344
# VEGETAZIONE_TIPO_Faggeta oligotrofica                                                                                0.109758
# VEGETAZIONE_TIPO_Pineta endalpica di greto di pino silvestre                                                         0.107762
# VEGETAZIONE_PRIORITA_Nessuna                                                                                         0.107343
# VEGETAZIONE_TIPO_Rimboschimento del piano subalpino                                                                  0.100493
# VEGETAZIONE_DESTINAZ_Fruizione                                                                                       0.093863
# Name: PC4, dtype: float64
#
# Top features for PC15:
# VEGETAZIONE_TIPO_Querceto mesoxerofilo di roverella delle Alpi                   0.510784
# VEGETAZIONE_TIPO_Pineta mesalpica basifila di pino silvestre                     0.449393
# VEGETAZIONE_TIPO_Faggeta eutrofica delle Alpi                                    0.351969
# VEGETAZIONE_TIPO_Arbusteto montano xerofilo di Prunus sp.pl/Berberis vulgaris    0.245923
# VEGETAZIONE_TIPO_Pineta endalpica mesoxerofila di pino silvestre                 0.240305
# VEGETAZIONE_TIPO_Querceto di rovere/roverella con orniello ed Erica cinerea      0.228789
# VEGETAZIONE_TIPO_Pineta mesalpica acidofila di pino silvestre                    0.203706
# VEGETAZIONE_TIPO_Faggeta oligotrofica                                            0.146059
# VEGETAZIONE_TIPO_Lariceto montano                                                0.137110
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                                   0.133529
# VEGETAZIONE_TIPO_Faggeta mesoxerofila                                            0.121795
# VEGETAZIONE_TIPO_Arbusteto rupestre di Amelanchier ovalis                        0.118978
# VEGETAZIONE_TIPO_Pineta di pino uncinato eretto                                  0.111061
# VEGETAZIONE_TIPO_Larici-cembreto su rodoreto-vaccinieto                          0.096080
# analfabeti                                                                       0.086607
# VEGETAZIONE_TIPO_Arbusteto montano di Buxus sempervirens                         0.086541
# VEGETAZIONE_TIPO_Rimboschimento del piano subalpino                              0.079349
# VEGETAZIONE_TIPO_Querco-carpineto d'alta pianura ad elevate precipitazioni       0.070592
# VEGETAZIONE_TIPO_Betuleto planiziale di brughiera                                0.069256
# VEGETAZIONE_TIPO_Abetina eutrofica                                               0.067860
# VEGETAZIONE_TIPO_Betuleto montano                                                0.065384
# VEGETAZIONE_TIPO_Faggeta altimontana a megaforbie                                0.063737
# VEGETAZIONE_TIPO_Querceto xero-acidofilo di roverella delle Alpi                 0.058902
# VEGETAZIONE_TIPO_Lariceto mesoxerofilo subalpino                                 0.056873
# VEGETAZIONE_TIPO_Pecceta montana mesalpica                                       0.054767
# VEGETAZIONE_TIPO_Faggeta basifila pioniera                                       0.053133
# VEGETAZIONE_TIPO_Alneto di ontano bianco                                         0.048219
# VEGETAZIONE_TIPO_Cerreta mesofila                                                0.043478
# VEGETAZIONE_TIPO_Pineta endalpica basifila di pino silvestre                     0.042957
# VEGETAZIONE_TIPO_Pineta di pino montano prostrato                                0.038165
# Name: PC15, dtype: float64
#
# Top features for PC5:
# VEGETAZIONE_DESTINAZ_Evoluzione libera senza specifica destinazione (superfici forestali)       0.312020
# Calma di vento (min)_season                                                                     0.273874
# VEGETAZIONE_ASSETTO_Bosco di neoformazione (invasione)                                          0.244493
# VEGETAZIONE_ASSETTO_Ceduo composto (Fustaia sopra ceduo / ceduo sotto fustaia)                  0.221543
# VEGETAZIONE_DESTINAZ_Produttiva                                                                 0.189373
# VEGETAZIONE_ASSETTO_Categorie di uso del suolo per cui non e' descritto un assetto evolutivo    0.186372
# VEGETAZIONE_PRIORITA_Medio termine - tra 6 e 10 anni                                            0.176520
# VEGETAZIONE_PRIORITA_Breve termine - entro 5 anni                                               0.174914
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale per collettivi                                 0.170654
# VEGETAZIONE_DESTINAZ_Filare                                                                     0.168693
# VEGETAZIONE_DESTINAZ_Categorie di uso del suolo per cui non e' prevista una destinazione        0.161211
# VEGETAZIONE_ASSETTO_Ceduo a sterzo (ceduo disetaneo)                                            0.154802
# VEGETAZIONE_INTERVENTO_Evoluzione controllata                                                   0.152332
# VEGETAZIONE_INTERVENTO_Diradamento e conversione                                                0.149827
# occupato                                                                                        0.143306
# VEGETAZIONE_DESTINAZ_Produttiva e protettiva                                                    0.140642
# VEGETAZIONE_DESTINAZ_Filare con arbusti o siepe arbustiva                                       0.132544
# Settore Prevalente_season                                                                       0.132208
# VEGETAZIONE_DESTINAZ_Fruizione                                                                  0.124458
# GP_RTP_4                                                                                        0.122739
# VEGETAZIONE_PRIORITA_Nessun intervento                                                          0.122163
# GP_RTP_2                                                                                        0.116672
# VEGETAZIONE_INTERVENTO_Evoluzione libera                                                        0.113958
# VEGETAZIONE_PRIORITA_Nessuna                                                                    0.113688
# VEGETAZIONE_INTERVENTO_Taglio a buche, a strisce, a fessura                                     0.110268
# VEGETAZIONE_INTERVENTO_Gestione a ceduo composto                                                0.104076
# Precipitazione dalle 0 alle 0 (mm)_season                                                       0.103358
# VEGETAZIONE_ASSETTO_Fustaia                                                                     0.100645
# VEGETAZIONE_TIPO_Specie esotiche o naturalizzate                                                0.098380
# VEGETAZIONE_TIPO_Pineta endalpica acidofila di pino silvestre                                   0.096779
# Name: PC5, dtype: float64
#
# Top features for PC17:
# Umidita' massima ( % )_season                                           0.481643
# Temperatura minima ( °C )_season                                        0.399837
# non forze di lavoro                                                     0.214866
# season                                                                  0.212084
# Umidita' media ( % )_season                                             0.209389
# Settore Prevalente_season                                               0.200436
# studente/ssa                                                            0.167448
# Velocita' massima raffica di vento ( m/s )_season                       0.166940
# occupato                                                                0.156932
# Radiazione totale ( MJ/mq )_season                                      0.143172
# Direzione massima raffica ( ° )_season                                  0.129947
# VEGETAZIONE_TIPO_Pineta endalpica basifila di pino silvestre            0.124456
# Precipitazione dalle 0 alle 0 (mm)_season                               0.121693
# YYYY                                                                    0.120574
# Calma di vento (min)_season                                             0.106145
# VEGETAZIONE_ASSETTO_Rimboschimento / fustaia artificiale                0.105372
# VEGETAZIONE_ASSETTO_Ceduo semplice con o senza matricine                0.104366
# VEGETAZIONE_ASSETTO_Fustaia                                             0.100191
# VEGETAZIONE_TIPO_Robinia pseudoacacia                                   0.096492
# VEGETAZIONE_ASSETTO_Ceduo a sterzo (ceduo disetaneo)                    0.089845
# casalinga/o                                                             0.088714
# VEGETAZIONE_TIPO_Abetina mesotrofica mesalpica                          0.088220
# analfabeti                                                              0.087107
# VEGETAZIONE_INTERVENTO_Mantenimento delle attuali pratiche colturali    0.083902
# VEGETAZIONE_ASSETTO_Bosco di neoformazione (invasione)                  0.082726
# VEGETAZIONE_TIPO_Abetina endalpica                                      0.080665
# Velocita' media del vento ( m/s )_season                                0.079703
# VEGETAZIONE_TIPO_Acero-tiglio-frassineto di forra                       0.078111
# VEGETAZIONE_INTERVENTO_Evoluzione controllata                           0.076941
# 15_24_forze di lavoro                                                   0.076471
# Name: PC17, dtype: float64
#
# Top features for PC10:
# occupato                                                                0.493392
# VEGETAZIONE_DESTINAZ_Fruizione                                          0.225308
# season                                                                  0.202480
# VEGETAZIONE_DESTINAZ_Produttiva e protettiva                            0.182145
# Temperatura minima ( °C )_season                                        0.167432
# VEGETAZIONE_PRIORITA_Medio termine - tra 6 e 10 anni                    0.164480
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale per collettivi         0.162449
# 15_24_occupato                                                          0.157551
# non forze di lavoro                                                     0.153405
# Velocita' massima raffica di vento ( m/s )_season                       0.139874
# VEGETAZIONE_ASSETTO_Governo misto                                       0.133160
# Temperatura media dei massimi ( °C )_season                             0.133094
# VEGETAZIONE_ASSETTO_Ceduo in conversione                                0.129750
# VEGETAZIONE_INTERVENTO_Taglio a scelta colturale                        0.127801
# VEGETAZIONE_ASSETTO_Rimboschimento / fustaia artificiale                0.126868
# VEGETAZIONE_INTERVENTO_Aree per cui non si prevede intervento           0.125772
# VEGETAZIONE_DESTINAZ_Protettiva                                         0.120233
# VEGETAZIONE_ASSETTO_Ceduo a sterzo (ceduo disetaneo)                    0.119770
# VEGETAZIONE_PRIORITA_Nessuna                                            0.118478
# Umidita' media ( % )_season                                             0.117768
# VEGETAZIONE_DESTINAZ_Filare                                             0.117039
# Tempo di permanenza nel settore ( min )_season                          0.112937
# VEGETAZIONE_ASSETTO_Ceduo semplice con o senza matricine                0.111869
# GP_RTP_4                                                                0.109325
# VEGETAZIONE_TIPO_Specie esotiche o naturalizzate                        0.108966
# VEGETAZIONE_TIPO_Pineta endalpica di greto di pino silvestre            0.107494
# VEGETAZIONE_ASSETTO_Fustaia                                             0.104147
# GP_RTP_3                                                                0.103218
# VEGETAZIONE_DESTINAZ_Produttiva                                         0.101005
# VEGETAZIONE_INTERVENTO_Mantenimento delle attuali pratiche colturali    0.100668
# Name: PC10, dtype: float64

# %% [markdown]
# ---
